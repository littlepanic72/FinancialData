# %%
# Pkg.add("PyPlot")
# Pkg.add("TimeSeries")
# Pkg.add("MarketTechnicals")
# Pkg.add("DecisionTree")
# Pkg.add("ScikitLearn")
# Pkg.update()

# %%
using Requests
using DataFrames
using TimeSeries
using MarketTechnicals
using PyPlot
using DecisionTree
using ScikitLearn

# %%
function getcsv(url)
    # with error checking
    r = Requests.get_streaming(url; timeout = 30.0)
    if r.response.status / 100 != 2
        error("Error downloading data")
    end
    df = readtable(r)
end

function yahoo(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    if length(colnames)>=7
        pop!(colnames)
        deleteat!(colnames,1)
    end
    dataarray=convert(Array, df[1:end,[2,3,4,7,6]])
    ta=TimeArray(timestamp,dataarray,colnames)
end

function quandl(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    if length(colnames)>=6
        deleteat!(colnames,1)
    end
    dataarray=convert(Array, df[2:end])
    ta=TimeArray(timestamp,dataarray,colnames)
end
# Out:
# WARNING: Method definition getcsv(Any) in module Main at In[1451]:3 overwritten at In[1488]:3.
# WARNING: Method definition yahoo(Any) in module Main at In[1451]:11 overwritten at In[1488]:11.
# WARNING: Method definition quandl(Any) in module Main at In[1451]:23 overwritten at In[1488]:23.
# quandl (generic function with 1 method)

# %%
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close")
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{Real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{Real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr"], ohlc.meta)
end
# Out:
# WARNING: Method definition averagetruerange(Any) in module Main at In[1452]:2 overwritten at In[1489]:2.
# WARNING: Method definition averagetruerange(Any, Any) in module Main at In[1452]:2 overwritten at In[1489]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any) in module Main at In[1452]:2 overwritten at In[1489]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any) in module Main at In[1452]:2 overwritten at In[1489]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any, Any) in module Main at In[1452]:2 overwritten at In[1489]:2.
# averagetruerange (generic function with 5 methods)

# %%
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    merge(mcd, sig, col_names=["macd", "signal"])
end
# Out:
# WARNING: Method definition macd2(Any) in module Main at In[1453]:2 overwritten at In[1490]:2.
# WARNING: Method definition macd2(Any, Any) in module Main at In[1453]:2 overwritten at In[1490]:2.
# WARNING: Method definition macd2(Any, Any, Any) in module Main at In[1453]:2 overwritten at In[1490]:2.
# WARNING: Method definition macd2(Any, Any, Any, Any) in module Main at In[1453]:2 overwritten at In[1490]:2.
# macd2 (generic function with 4 methods)

# %%
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Float64,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Float64,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pflow=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nflow=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pflow,sum,n)
    nsum=moving(nflow,sum,n)
    flowsum=psum.+nsum
    re=psum./flowsum
    TimeArray(re.timestamp, re.values, ["mfi"], ohlcv.meta)
end
# Out:
# WARNING: Method definition moneyflowindex(Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# WARNING: Method definition moneyflowindex(Any, Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any, Any) in module Main at In[1454]:2 overwritten at In[1491]:2.
# moneyflowindex (generic function with 6 methods)

# %%
function chaikinmoneyflow(ohlcv, n=20, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = ((cl.-lo).-(hi.-cl))./(hi.-lo).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf"], ohlcv.meta)
end
# Out:
# WARNING: Method definition chaikinmoneyflow(Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any, Any) in module Main at In[1455]:2 overwritten at In[1492]:2.
# chaikinmoneyflow (generic function with 6 methods)

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
# Out:
# WARNING: Method definition overlaps(Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[1456]:2 overwritten at In[1493]:2.
# overlaps (generic function with 1 method)

# %%
function mergetimearray(ta1, ta2)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, [ta1.colnames; ta2.colnames])
end
# Out:
# WARNING: Method definition mergetimearray(Any, Any) in module Main at In[1457]:2 overwritten at In[1494]:2.
# mergetimearray (generic function with 1 method)

# %%
function pricerangeindex(ta, n=26)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=mergetimearray(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["pricerange"]])
end
# Out:
# WARNING: Method definition pricerangeindex(Any) in module Main at In[1458]:2 overwritten at In[1495]:2.
# WARNING: Method definition pricerangeindex(Any, Any) in module Main at In[1458]:2 overwritten at In[1495]:2.
# pricerangeindex (generic function with 2 methods)

# %%
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
# Out:
# WARNING: Method definition bollingerbands2(TimeSeries.TimeArray{#T<:Any, #N<:Any, M<:Any}, Int64, Real) in module Main at In[1459]:2 overwritten at In[1496]:2.
# bollingerbands2 (generic function with 1 method)

# %%
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=mergetimearray(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev", "bbstd"])
end
# Out:
# WARNING: Method definition bollingerbands_deviation(Any) in module Main at In[1460]:2 overwritten at In[1497]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any) in module Main at In[1460]:2 overwritten at In[1497]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any, Any) in module Main at In[1460]:2 overwritten at In[1497]:2.
# bollingerbands_deviation (generic function with 3 methods)

# %%
function moneyflow_deviation(rsi, mfi)
    rm=mergetimearray(rsi,mfi)
    mfdev=TimeArray(rm.timestamp,rm.values[:,2]-rm.values[:,1],["moneyflowdev"])
    mfdevema=ema(mfdev,6)
    TimeArray(mfdevema.timestamp,mfdevema.values,["mfidev"])
end
# Out:
# WARNING: Method definition moneyflow_deviation(Any, Any) in module Main at In[1461]:2 overwritten at In[1498]:2.
# moneyflow_deviation (generic function with 1 method)

# %%
# Financial data sets
url1="http://real-chart.finance.yahoo.com/table.csv?s=TQQQ&a=00&b=1&c=2015&d=04&e=5&f=2016&g=d&ignore=.csv";
url2="https://www.quandl.com/api/v3/datasets/GOOG/NASDAQ_TQQQ.csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date=2011-01-01&end_date=2016-05-05";

# %%
splitoffset=252;
# tqqq=yahoo(url1)
tqqq=quandl(url2)
# Out:
# 1343x5 TimeSeries.TimeArray{Float64,2,DataType} 2011-01-03 to 2016-05-04
#
#              Open      High      Low       Close     Volume
# 2011-01-03 | 18.98     19.7      18.97     19.32     2780896
# 2011-01-04 | 19.56     19.57     18.92     19.29     2739672
# 2011-01-05 | 19.1      19.78     19.07     19.77     2559952
# 2011-01-06 | 19.84     19.99     19.72     19.95     2177616
# ⋮
# 2016-04-29 | 93.79     94.56     90.3      92.61     3979704
# 2016-05-02 | 93.19     95.49     92.05     95.06     2454373
# 2016-05-03 | 93.07     94.32     91.68     92.53     3023488
# 2016-05-04 | 90.83     91.77     89.98     90.7      3232169

# %%
rsiarray=rsi(ta)./100;

# %%
ta=tqqq["Close"];
atrarray=averagetruerange(tqqq);
atrarray26=averagetruerange(tqqq,26);
macdarray=macd2(ta);
rsiarray=rsi(ta)./100;
mfiarray=moneyflowindex(tqqq);
cmfarray=chaikinmoneyflow(tqqq);
bbarray=bollingerbands_deviation(ta);
mfidevarray=moneyflow_deviation(rsiarray, mfiarray)
rangeindexarray=pricerangeindex(ta);

# %%
featurearray=mergetimearray(atrarray,rsiarray);

# %%
featurearray=mergetimearray(featurearray,mfiarray);

# %%
featurearray=mergetimearray(featurearray,mfidevarray);

# %%
featurearray=mergetimearray(featurearray,cmfarray);

# %%
featurearray=mergetimearray(featurearray,bbarray);

# %%
featurearray=mergetimearray(featurearray,macdarray);

# %%
featurearray=mergetimearray(featurearray,atrarray26);

# %%
featurearray1=mergetimearray(featurearray,rangeindexarray);

# %%
featurearray2=mergetimearray(featurearray,ta);

# %%
splitdate=featurearray1.timestamp[end]
# Out:
# 2016-03-30

# %%
idx=searchsortedfirst(featurearray2.timestamp, splitdate)-splitoffset
# Out:
# 1033

# %%
oldfeatures=TimeArray(featurearray1.timestamp[1:idx],featurearray1.values[1:idx,:],featurearray1.colnames)
# Out:
# 1033x14 TimeSeries.TimeArray{Float64,2,DataType} 2011-02-18 to 2015-03-30
#
#              atr     rsi     mfi     mfidev  cmf     bbdev   bbstd   macd    signal  atr     Close     min       max       pricerange
# 2011-02-18 | 0.6271  0.7423  0.9028  -0.0482 0.4007  0.6464  1.042   0.8073  0.6967  0.6607  23.0      17.82     23.0      1.0
# 2011-02-22 | 0.7337  0.332   0.3897  -0.018  0.2649  -0.3465 1.0202  0.6355  0.6845  0.7168  20.97     17.82     22.29     0.7047
# 2011-02-23 | 0.7678  0.2854  0.3103  -0.0057 0.2071  -0.595  1.0265  0.4522  0.638   0.7358  20.45     17.82     22.29     0.5884
# 2011-02-24 | 0.7808  0.3446  0.3201  -0.0111 0.2227  -0.4478 1.0323  0.3265  0.5757  0.744   20.74     17.82     22.29     0.6532
# ⋮
# 2015-03-25 | 3.6536  0.3428  0.3044  -0.1592 -0.1104 -0.7361 4.052   0.9494  1.3887  3.6167  102.45    101.25    117.36    0.0745
# 2015-03-26 | 3.6941  0.3264  0.2799  -0.127  -0.1285 -0.7473 4.1791  0.39    1.189   3.6399  101.61    101.25    117.36    0.0223
# 2015-03-27 | 3.6038  0.3672  0.2976  -0.1106 -0.1004 -0.5682 4.2508  0.0255  0.9563  3.5934  102.59    101.25    117.36    0.0832
# 2015-03-30 | 3.6242  0.4991  0.4361  -0.097  -0.0848 -0.0937 3.9506  0.034   0.7718  3.6048  106.28    101.25    117.36    0.3122

# %%
newfeatures=TimeArray(featurearray2.timestamp[idx+1:end],featurearray2.values[idx+1:end,:],featurearray2.colnames)
# Out:
# 277x11 TimeSeries.TimeArray{Float64,2,DataType} 2015-03-31 to 2016-05-04
#
#              atr     rsi     mfi     mfidev  cmf     bbdev   bbstd    macd    signal  atr     Close
# 2015-03-31 | 3.6146  0.411   0.463   -0.0544 -0.1425 -0.4642 3.8204   -0.2222 0.573   3.6004  102.99
# 2015-04-01 | 3.6236  0.371   0.408   -0.0283 -0.153  -0.6264 3.8141   -0.5592 0.3466  3.6057  101.25
# 2015-04-02 | 3.504   0.3778  0.4217  -0.0077 -0.1557 -0.5536 3.6893   -0.8033 0.1166  3.5421  101.42
# 2015-04-06 | 3.6516  0.4726  0.4034  -0.0252 -0.0824 -0.1962 3.6576   -0.7907 -0.0649 3.6201  103.86
# ⋮
# 2016-04-29 | 3.9478  0.1889  0.2471  0.0373  0.0105  -1.2044 4.1821   -0.3994 1.4704  4.0949  92.61
# 2016-05-02 | 3.9115  0.324   0.2876  0.0162  0.0591  -0.7994 4.473    -0.754  1.0255  4.0697  95.06
# 2016-05-03 | 3.8736  0.2703  0.104   -0.0359 0.0667  -0.9323 4.9468   -1.2251 0.5754  4.0432  92.53
# 2016-05-04 | 3.779   0.2375  0.0758  -0.0719 -0.0026 -0.956  5.3662   -1.7263 0.1151  3.9857  90.7

# %%
plot(oldfeatures.timestamp,oldfeatures.values[:,1:10])
legend(oldfeatures.colnames[1:10])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f05236672d0>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
using DecisionTree
using ScikitLearn
using PyPlot

# %%
ntrees=100
closeidx=11
pricerangeidx=14
features=oldfeatures.values[:,1:closeidx]
labels=oldfeatures.values[:,pricerangeidx]
model = build_forest(labels,features, 2, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 244.87
# Avg Depth:  19.7

# %%
newlabels=apply_forest(model, newfeatures.values);

# %%
initvalue=oldfeatures.values[1,11]*2
# Out:
# 46.0

# %%
plot(oldfeatures.timestamp,oldfeatures.values[:,closeidx:pricerangeidx-1]./initvalue)
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue,c="b")
plot(oldfeatures.timestamp,labels,c="Purple")
plot(newfeatures.timestamp,newlabels,c="Purple",linewidth=2)
plot(oldfeatures.timestamp,oldfeatures.values[:,2],c="y")
plot(newfeatures.timestamp,newfeatures.values[:,2],c="y")
plot(oldfeatures.timestamp,oldfeatures.values[:,3],c="c")
plot(newfeatures.timestamp,newfeatures.values[:,3],c="c")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f05241d4550>)

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue,c="b")
plot(newfeatures.timestamp,newlabels,c="Purple",linewidth=2)
plot(newfeatures.timestamp,newfeatures.values[:,2],c="y")
plot(newfeatures.timestamp,newfeatures.values[:,3],c="c")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f05243d08d0>)
