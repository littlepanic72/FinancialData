# %%
using DataFrames
using Requests
using TimeSeries
using MarketTechnicals
using PyPlot
# Out:
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:6
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:6
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:6
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:6
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:6
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: New definition
#     write(GZip.GZipStream, Array{#T<:Any, N<:Any}) at /home/juser/.julia/v0.5/GZip/src/GZip.jl:456
# is ambiguous with:
#     write(Base.IO, Array{UInt8, N<:Any}) at io.jl:154.
# To fix, define
#     write(GZip.GZipStream, Array{UInt8, N<:Any})
# before the new definition.
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
# WARNING: readbytes is deprecated, use read instead. [inlined code] from
# ./error.jl:26
#  [inlined code] from  in ./error.jldepwarn:(26
# :: in ASCIIStringdepwarn, (::Symbol)::ASCIIString,  at ./deprecated.jl:64
# :: in Symbol)Union( at ./deprecated.jl:64
# :: in Typereadbytes{(Array{Date,1}}, ::Base.PipeEndpoint, ::Type{Array{DateTime,1}})::Vararg{Any}) at ./deprecated.jl:50
#  at  in ./deprecated.jlinclude:(30
# :: in ASCIIStringsend_stream)( at ./boot.jl:240
# :: in Baseinclude_from_node1.(PipeEndpoint, ::ASCIIString)::ASCIIString) at ./loading.jl:417
#  at  in /opt/julia_packages/.julia/v0.5/IJulia/src/stdio.jlinclude:(25
# :: in ASCIIStringwatch_stream)( at ./boot.jl:240
# :: in Baseinclude_from_node1.(PipeEndpoint, ::ASCIIString)::ASCIIString) at ./loading.jl:417
#  at  in /opt/julia_packages/.julia/v0.5/IJulia/src/stdio.jleval:(41
# :: in Module, (::IJulia.##6#10)(::)Any) at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 7 at
# ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Array{Date,1}}, ::Type{Array{DateTime,1}}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 7
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Array{Date,1}}, ::Type{Array{DateTime,1}}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 29
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:30
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Date}, ::Type{DateTime}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 30
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Array{Date,1}}, ::Type{Array{DateTime,1}}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 33
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Date}, ::Type{DateTime}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 34
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:169
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:175
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Date}, ::Type{DateTime}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 181
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Array{Date,1}}, ::Type{Array{DateTime,1}}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 192
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{StepRange{Date,S}}, ::Type{StepRange{DateTime,S}}) at ./deprecated.jl:50
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 204
# WARNING: module TimeSeries should explicitly import .+ from Base
# WARNING: module TimeSeries should explicitly import .- from Base
# WARNING: module TimeSeries should explicitly import .* from Base
# WARNING: module TimeSeries should explicitly import ./ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import .^ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import + from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import - from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import * from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import / from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import ^ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: module TimeSeries should explicitly import .> from Base
# WARNING: module TimeSeries should explicitly import .< from Base
# WARNING: module TimeSeries should explicitly import .== from Base
# WARNING: module TimeSeries should explicitly import .>= from Base
# WARNING: module TimeSeries should explicitly import .<= from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.

# %%
function getcsv(url)
    # without error checking
    df = readtable(Requests.get_streaming(url))
end
function csvtotimearray(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    dataarray=convert(Array, df[2:end])
    TimeArray(timestamp,dataarray,colnames[2:end])
end
# function csvtotimearray_adjustclose(url)
#     df = getcsv(url)
#     timestamp = Date[Date(i) for i in df[1]] # parse dates
#     colnames=AbstractString[string(i) for i in DataFrames.names(df)]
#     dataarray=convert(Array, df[[2,3,4,7,6]])
#     TimeArray(timestamp,dataarray,colnames[2:end-1])
# end
function yahoo(symbol, startdate)
    str="a="*string(Dates.month(startdate)-1)*Dates.format(startdate, "&b=dd&c=yyyy")
    url="http://real-chart.finance.yahoo.com/table.csv?s="*symbol*"&"*str*"&g=d&ignore=.csv"
    csvtotimearray(url)
end
function quandl(symbol, startdate)
    str=Dates.format(startdate, "yyyy-mm-dd")
    url="https://www.quandl.com/api/v3/datasets/"*symbol*".csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date="*str
    csvtotimearray(url)
end
# Out:
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{Int64}, ::Type{Float64}) at ./deprecated.jl:50
#  [inlined code] from /home/juser/.julia/v0.5/TimeSeries/src/TimeSeries.jl:7
#  in anonymous at ./<no file>:4294967295
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in include(::ASCIIString) at ./boot.jl:240
#  in include_from_node1(::ASCIIString) at ./loading.jl:417
#  in eval(::Module, ::Any) at ./boot.jl:243
#  [inlined code] from ./sysimg.jl:11
#  in require(::Symbol) at ./loading.jl:348
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/readwrite.jl:3
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/readwrite.jl:3
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/readwrite.jl:3
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/readwrite.jl:3
# WARNING: requiring "Dates" in module "MarketTechnicals" did not define a corresponding module.
# quandl (generic function with 1 method)

# %%
symbol="QQQ"
startdate=Date(2010,1,1)
ohlcv=yahoo(symbol, startdate)
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:3
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# 1597x6 TimeSeries.TimeArray{Real,2,DataType} 2010-01-04 to 2016-05-06
#
#              Open      High      Low       Close     Volume          Adj_Close
# 2010-01-04 | 46.33     46.49     46.27     46.42     62822800        43.2453
# 2010-01-05 | 46.39     46.5      46.16     46.42     62935600        43.2453
# 2010-01-06 | 46.4      46.55     46.07     46.14     96033000        42.9844
# 2010-01-07 | 46.21     46.27     45.92     46.17     77094100        43.0124
# ⋮
# 2016-05-03 | 105.96    106.44    105.45    105.73    36351400        105.73
# 2016-05-04 | 105.12    105.48    104.79    105.05    26689000        105.05
# 2016-05-05 | 105.43    105.66    104.81    105.02    20724800        105.02
# 2016-05-06 | 104.5     105.6     104.4     105.58    29731500        105.58
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:31
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:31
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:31
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:31
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl
# WARNING: Base.SingleAsyncWork is deprecated, use Base.AsyncCondition instead.
#   likely near /opt/julia_packages/.julia/v0.5/IJulia/src/kernel.jl:31
# in gc_protect_handle at /opt/julia_packages/.julia/v0.5/ZMQ/src/ZMQ.jl

# %%
# ohlcv=quandl("GOOG/NASDAQ_QQQ",startdate)

# %%
ta=ohlcv["Close"]
vix=quandl("CBOE/VIX", startdate)
vixarray=TimeArray(vix.timestamp,vix.values[:,end],[vix.colnames[end]])
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[41]:3
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# 1596x1 TimeSeries.TimeArray{Float64,1,DataType} 2010-01-04 to 2016-05-05
#
#              VIX_Close
# 2010-01-04 | 20.04
# 2010-01-05 | 19.35
# 2010-01-06 | 19.16
# 2010-01-07 | 19.06
# ⋮
# 2016-05-02 | 14.68
# 2016-05-03 | 15.6
# 2016-05-04 | 16.05
# 2016-05-05 | 15.91

# %%
ustreasuryarray=quandl("USTREASURY/REALLONGTERM", startdate)
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[6]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[6]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[6]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[6]:1
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[6]:1
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# 1589x1 TimeSeries.TimeArray{Float64,2,DataType} 2010-01-04 to 2016-05-06
#
#              LT_Real_Average_10Yrs_
# 2010-01-04 | 2.02
# 2010-01-05 | 1.96
# 2010-01-06 | 2.01
# 2010-01-07 | 1.99
# ⋮
# 2016-05-03 | 0.67
# 2016-05-04 | 0.66
# 2016-05-05 | 0.62
# 2016-05-06 | 0.66

# %%
oil=quandl("EOD/OIL", startdate)
oilarray=TimeArray(oil.timestamp,oil.values[:,end-1],["oil"])
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:2
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:2
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:2
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:2
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:2
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# 1597x1 TimeSeries.TimeArray{Float64,1,DataType} 2010-01-04 to 2016-05-06
#
#              oil
# 2010-01-04 | 26.58
# 2010-01-05 | 26.7
# 2010-01-06 | 27.09
# 2010-01-07 | 26.93
# ⋮
# 2016-05-03 | 5.67
# 2016-05-04 | 5.7
# 2016-05-05 | 5.77
# 2016-05-06 | 5.8

# %%
gold=quandl("WGC/GOLD_DAILY_USD", startdate)
goldarray=TimeArray(gold.timestamp,gold.values[:,end],["gold_usd"])
# Out:
# 1656x1 TimeSeries.TimeArray{Float64,1,DataType} 2010-01-01 to 2016-05-06
#
#              gold_usd
# 2010-01-01 | 1087.5
# 2010-01-04 | 1121.5
# 2010-01-05 | 1123.25
# 2010-01-06 | 1130.0
# ⋮
# 2016-05-03 | 1294.0
# 2016-05-04 | 1283.0
# 2016-05-05 | 1280.3
# 2016-05-06 | 1289.0

# %%
splitoffset=252-24
rangelength=28
# Out:
# 28

# %%
function volumeoscillator(ohlcv, n=28, c="Volume")
    volume=ohlcv[c]
    vshort=ema(volume, Int(n/2))
    vlong=ema(volume, n)
    volumeoscillator=(vshort.-vlong)./vlong
    TimeArray(volumeoscillator.timestamp,volumeoscillator.values,["VolumeOscillator"])
end
# Out:
# WARNING: Method definition volumeoscillator(Any) in module Main at In[10]:2 overwritten at In[43]:2.
# WARNING: Method definition volumeoscillator(Any, Any) in module Main at In[10]:2 overwritten at In[43]:2.
# WARNING: Method definition volumeoscillator(Any, Any, Any) in module Main at In[10]:2 overwritten at In[43]:2.
# volumeoscillator (generic function with 3 methods)

# %%
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close")
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{Real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{Real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr"*string(n)], ohlc.meta)
end
# Out:
# WARNING: Method definition averagetruerange(Any) in module Main at In[11]:2 overwritten at In[44]:2.
# WARNING: Method definition averagetruerange(Any, Any) in module Main at In[11]:2 overwritten at In[44]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any) in module Main at In[11]:2 overwritten at In[44]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any) in module Main at In[11]:2 overwritten at In[44]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any, Any) in module Main at In[11]:2 overwritten at In[44]:2.
# averagetruerange (generic function with 5 methods)

# %%
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    merge(mcd, sig, col_names=["macd", "signal"])
end
# Out:
# WARNING: Method definition macd2(Any) in module Main at In[12]:2 overwritten at In[45]:2.
# WARNING: Method definition macd2(Any, Any) in module Main at In[12]:2 overwritten at In[45]:2.
# WARNING: Method definition macd2(Any, Any, Any) in module Main at In[12]:2 overwritten at In[45]:2.
# WARNING: Method definition macd2(Any, Any, Any, Any) in module Main at In[12]:2 overwritten at In[45]:2.
# macd2 (generic function with 4 methods)

# %%
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pflow=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nflow=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pflow,sum,n)
    nsum=moving(nflow,sum,n)
    flowsum=psum.+nsum
    re=psum./flowsum
    TimeArray(re.timestamp, re.values, ["mfi"], ohlcv.meta)
end
# Out:
# WARNING: Method definition moneyflowindex(Any) in module Main at In[13]:2 overwritten at In[46]:2.
# WARNING: Method definition moneyflowindex(Any, Any) in module Main at In[13]:2 overwritten at In[46]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any) in module Main at In[13]:2 overwritten at In[46]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any) in module Main at In[13]:2 overwritten at In[46]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any) in module Main at In[13]:2 overwritten at In[46]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any, Any) in module Main at In[13]:2 overwritten at In[46]:2.
# moneyflowindex (generic function with 6 methods)

# %%
function chaikinmoneyflow(ohlcv, n=21, h="High", l="Low", c="Close", v="Volume")
    high=ohlcv[h]
    low=ohlcv[l]
    clo=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = (2.*clo.-low.-high)./(high.-low).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf"*string(n)], ohlcv.meta)
end
# Out:
# WARNING: Method definition chaikinmoneyflow(Any) in module Main at In[14]:2 overwritten at In[47]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any) in module Main at In[14]:2 overwritten at In[47]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any) in module Main at In[14]:2 overwritten at In[47]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any) in module Main at In[14]:2 overwritten at In[47]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any) in module Main at In[14]:2 overwritten at In[47]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any, Any) in module Main at In[14]:2 overwritten at In[47]:2.
# chaikinmoneyflow (generic function with 6 methods)

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
# Out:
# WARNING: Method definition overlaps(Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[15]:2 overwritten at In[48]:2.
# overlaps (generic function with 1 method)

# %%
function mergetimearray(ta1, ta2)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, [ta1.colnames; ta2.colnames])
end
# Out:
# WARNING: Method definition mergetimearray(Any, Any) in module Main at In[16]:2 overwritten at In[49]:2.
# mergetimearray (generic function with 1 method)

# %%
function pricerangeindex(ta, n=28)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=mergetimearray(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["pricerange"*string(n)]])
end
# Out:
# WARNING: Method definition pricerangeindex(Any) in module Main at In[17]:2 overwritten at In[50]:2.
# WARNING: Method definition pricerangeindex(Any, Any) in module Main at In[17]:2 overwritten at In[50]:2.
# pricerangeindex (generic function with 2 methods)

# %%
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
# Out:
# WARNING: Method definition bollingerbands2(TimeSeries.TimeArray{#T<:Any, #N<:Any, M<:Any}, Int64, Real) in module Main at In[18]:2 overwritten at In[51]:2.
# bollingerbands2 (generic function with 1 method)

# %%
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=mergetimearray(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev"*string(n)*","*string(width), "bbstd"*string(n)*","*string(width)])
end
# Out:
# WARNING: Method definition bollingerbands_deviation(Any) in module Main at In[19]:2 overwritten at In[52]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any) in module Main at In[19]:2 overwritten at In[52]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any, Any) in module Main at In[19]:2 overwritten at In[52]:2.
# bollingerbands_deviation (generic function with 3 methods)

# %%
function moneyflow_divergence(rsi, mfi, n=14)
    rm=mergetimearray(rsi,mfi)
    diff=rm.values[:,2].-rm.values[:,1]
    mfdev=TimeArray(rm.timestamp,diff,["moneyflowdev"])
    mfdevema=ema(mfdev,6)
    TimeArray(mfdevema.timestamp,mfdevema.values,["mfi_divergence_"*string(n)])
end
# Out:
# WARNING: Method definition moneyflow_divergence(Any, Any) in module Main at In[20]:2 overwritten at In[53]:2.
# WARNING: Method definition moneyflow_divergence(Any, Any, Any) in module Main at In[20]:2 overwritten at In[53]:2.
# moneyflow_divergence (generic function with 2 methods)

# %%
rsiarray=rsi(ta)./100;
rsiarray2=rsi(ta,rangelength)./100;

# %%
atrarray=averagetruerange(ohlcv);
atrarray2=averagetruerange(ohlcv,rangelength);

# %%
mfiarray=moneyflowindex(ohlcv);
mfiarray2=moneyflowindex(ohlcv,rangelength);

# %%
mfidivarray=moneyflow_divergence(rsiarray,mfiarray);
mfidivarray2=moneyflow_divergence(rsiarray2,atrarray2, rangelength);

# %%
volumeoscillatorarray=volumeoscillator(ohlcv, rangelength);
macdarray=macd2(ta);
cmfarray=chaikinmoneyflow(ohlcv);
bbarray=bollingerbands_deviation(ta);
emaarray=ema(ta,20);
rangeindexarray=pricerangeindex(ta, rangelength);

# %%
featurearray=mergetimearray(atrarray,rsiarray);
featurearray=mergetimearray(featurearray,mfiarray);
featurearray=mergetimearray(featurearray,mfidivarray);
featurearray=mergetimearray(featurearray,cmfarray);
featurearray=mergetimearray(featurearray,bbarray);
featurearray=mergetimearray(featurearray,macdarray);
featurearray=mergetimearray(featurearray,volumeoscillatorarray);

# %%
featurearray=mergetimearray(featurearray,atrarray2);
featurearray=mergetimearray(featurearray,rsiarray2);
featurearray=mergetimearray(featurearray,mfiarray2);
featurearray=mergetimearray(featurearray,mfidivarray2);
featurearray=mergetimearray(featurearray,ustreasuryarray);
featurearray=mergetimearray(featurearray,emaarray);
featurearray=mergetimearray(featurearray,vixarray);
featurearray=mergetimearray(featurearray,oilarray);
featurearray=mergetimearray(featurearray,goldarray);

# %%
featurearray1=mergetimearray(featurearray,rangeindexarray);
featurearray2=mergetimearray(featurearray,ta);

# %%
sidx=searchsortedfirst(featurearray2.timestamp, featurearray1.timestamp[end])-splitoffset
oldfeatures=TimeArray(featurearray1.timestamp[1:sidx],featurearray1.values[1:sidx,:],featurearray1.colnames)
# Out:
# 1297x23 TimeSeries.TimeArray{Real,2,DataType} 2010-02-22 to 2015-04-30
#
#              atr14   rsi     mfi     mfi_divergence_14  cmf21   bbdev20,2  bbstd20,2  macd    signal  VolumeOscillator  atr28   rsi     mfi     mfi_divergence_28  LT_Real_Average_10Yrs_  ema20     VIX_Close  oil      gold_usd   Close     min       max       pricerange28
# 2010-02-22 | 0.6931  0.6472  0.5807  -0.1717            0.0458  0.6422     0.7459     -0.4099 -0.867  -0.0935           0.7385  0.4897  0.2852  0.2977             2.14                    44.3496   19.94      25.77    1115.3     44.74     44.16     48.39     0.1371
# 2010-02-23 | 0.7     0.5021  0.4861  -0.1272            0.0852  0.26       0.7412     -0.383  -0.7702 -0.0894           0.7403  0.4376  0.2859  0.2991             2.1                     44.3315   21.37      25.29    1107.0     44.16     44.16     48.39     0.0
# 2010-02-24 | 0.695   0.5853  0.4856  -0.1194            0.1084  0.5459     0.7534     -0.3217 -0.6805 -0.0914           0.7364  0.4834  0.2813  0.2859             2.12                    44.3581   20.27      25.77    1103.0     44.61     44.6      48.61     0.0025
# 2010-02-25 | 0.7075  0.5828  0.6223  -0.074             0.1573  0.5467     0.7476     -0.2708 -0.5985 -0.0847           0.7412  0.4825  0.2676  0.2782             2.11                    44.3811   20.1       25.15    1094.5     44.6      44.6      48.75     0.0
# ⋮
# 2015-04-27 | 1.2079  0.7141  0.6677  -0.0628            0.1455  0.9847     1.4943     0.7983  0.4319  0.0094            1.2128  0.6425  0.5226  0.5969             0.44                    107.8814  13.12      11.8     1200.0     110.26    106.71    110.96    0.8353
# 2015-04-28 | 1.2245  0.6822  0.6068  -0.0664            0.1383  0.7994     1.5997     0.8681  0.5191  0.0261            1.2209  0.628   0.4794  0.5958             0.52                    108.087   12.41      11.85    1209.0     110.04    106.71    110.96    0.7835
# 2015-04-29 | 1.2313  0.587   0.55    -0.058             0.0917  0.529      1.5878     0.8578  0.5869  0.0369            1.2245  0.5835  0.4469  0.6087             0.56                    108.2073  13.39      12.19    1209.0     109.35    106.71    110.96    0.6212
# 2015-04-30 | 1.3069  0.4189  0.4301  -0.0382            0.1045  -0.0575    1.4701     0.7027  0.61    0.0659            1.2625  0.4905  0.3853  0.6554             0.53                    108.1523  14.55      12.46    1180.3     107.63    106.71    110.96    0.2165

# %%
newfeatures=TimeArray(featurearray2.timestamp[sidx+1:end],featurearray2.values[sidx+1:end,:],featurearray2.colnames)
# Out:
# 254x20 TimeSeries.TimeArray{Real,2,DataType} 2015-05-01 to 2016-05-05
#
#              atr14   rsi     mfi     mfi_divergence_14  cmf21   bbdev20,2  bbstd20,2  macd    signal  VolumeOscillator  atr28   rsi     mfi     mfi_divergence_28  LT_Real_Average_10Yrs_  ema20     VIX_Close  oil      gold_usd   Close
# 2015-05-01 | 1.32    0.5434  0.4655  -0.0496            0.15    0.3885     1.3572     0.6865  0.6253  0.0646            1.2706  0.5536  0.4121  0.673              0.59                    108.2378  12.7       12.39    1176.0     109.05
# 2015-05-04 | 1.2871  0.5573  0.5099  -0.049             0.1144  0.4125     1.2995     0.6804  0.6363  0.0436            1.256   0.561   0.4301  0.6793             0.66                    108.3323  12.85      12.29    1176.0     109.23
# 2015-05-05 | 1.3259  0.4138  0.4056  -0.0373            0.0056  -0.3306    1.1954     0.5258  0.6142  0.076             1.2765  0.477   0.4341  0.7136             0.66                    108.2483  14.31      12.64    1197.0     107.45
# 2015-05-06 | 1.3705  0.3683  0.3662  -0.0273            0.018   -0.6441    1.1908     0.3397  0.5593  0.0895            1.3005  0.4471  0.4471  0.7536             0.75                    108.1018  15.15      12.69    1194.3     106.71
# ⋮
# 2016-05-02 | 1.4389  0.3373  0.2222  -0.0368            0.0619  -0.777     1.5956     -0.2215 0.4258  0.0538            1.5329  0.419   0.3679  1.0994             0.68                    108.4159  14.68      5.87     1285.7     106.72
# 2016-05-03 | 1.4268  0.2789  0.0825  -0.0824            0.0415  -0.9378    1.7658     -0.3954 0.2616  0.0636            1.5236  0.3801  0.3613  1.112              0.67                    108.1601  15.6       5.67     1294.0     105.73
# 2016-05-04 | 1.392   0.2452  0.0756  -0.1073            0.0509  -0.9642    1.9244     -0.5814 0.093   0.0504            1.5027  0.3557  0.3513  1.122              0.66                    107.8639  16.05      5.7      1283.0     105.05
# 2016-05-05 | 1.3533  0.2437  0.0798  -0.1235            -0.0082 -0.8475    2.0873     -0.7228 -0.0702 0.0263            1.4794  0.3546  0.3496  1.1228             0.62                    107.593   15.91      5.77     1280.3     105.02

# %%
rsiidx=findlast(oldfeatures.colnames,"rsi")
mfiidx=findlast(oldfeatures.colnames,"mfi")
closeidx=findfirst(oldfeatures.colnames,"Close")
# Out:
# 20

# %%
ignore=5;
plot(oldfeatures.timestamp,oldfeatures.values[:,1:closeidx-ignore])
legend(oldfeatures.colnames[1:closeidx-ignore],bbox_to_anchor=(1.52, 1.02))
title("Features for training")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4c55c12a90>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
# plot(oldfeatures.timestamp,oldfeatures.values[:,closeidx-ignore+1:closeidx-2])
# legend(oldfeatures.colnames[closeidx-ignore+1:closeidx-2],bbox_to_anchor=(1.52, 1.02))
# title("features for training")

# %%
# plot(oldfeatures.timestamp,oldfeatures.values[:,closeidx-1])
# legend([oldfeatures.colnames[closeidx-1]],bbox_to_anchor=(1.52, 1.02))
# title("features for training")

# %%
using DecisionTree
using ScikitLearn

# %%
ntrees=100
pricerangeidx=closeidx+3
features=oldfeatures.values[:,1:closeidx]
labels=convert(Array{Float64,1},oldfeatures.values[:,pricerangeidx])
model = build_forest(labels,features, 2, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 307.54
# Avg Depth:  21.44

# %%
newlabels=apply_forest(model, newfeatures.values);

# %%
initvalue=oldfeatures.values[1,closeidx]
# Out:
# 44.740002

# %%
plot(oldfeatures.timestamp,oldfeatures.values[:,closeidx:pricerangeidx-1]./initvalue)
plot(oldfeatures.timestamp,labels,c="m")
plot([oldfeatures.timestamp;newfeatures.timestamp],[oldfeatures.values[:,rsiidx];newfeatures.values[:,rsiidx]],c="y")
plot([oldfeatures.timestamp;newfeatures.timestamp],[oldfeatures.values[:,mfiidx];newfeatures.values[:,mfiidx]],c="c")
plot(newfeatures.timestamp,newlabels,c="DarkMagenta",linewidth=1.5)
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue,c="b")
title(symbol*" history & forecast")
grid("on")
legend([oldfeatures.colnames[[closeidx,closeidx+1,closeidx+2,pricerangeidx,rsiidx,mfiidx]];"price range forecast"],bbox_to_anchor=(1.46, 1.02))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4c5549e2d0>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue,c="b")
plot(newfeatures.timestamp,newfeatures.values[:,rsiidx],c="y")
plot(newfeatures.timestamp,newfeatures.values[:,mfiidx],c="c")
plot(newfeatures.timestamp,newlabels,c="DarkMagenta",linewidth=1.5)
legend([oldfeatures.colnames[[closeidx,rsiidx,mfiidx]];"price range forecast"],bbox_to_anchor=(1.46, 1.02))
title(symbol*" forecast: random forest with "*string(ntrees)*" trees"*", period="*string(rangelength))
grid("on")
# color names http://astropython.blogspot.ie/2012/02/additional-color-names-for-matplotlib.html
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4c552bc8d0>)
