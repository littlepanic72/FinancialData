# %%
using DataFrames
using Requests
using TimeSeries
using MarketTechnicals
using PyPlot

# %%
function getcsv(url)
    # without error checking
    df = readtable(Requests.get_streaming(url))
end
function csvtotimearray(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    dataarray=convert(Array, df[2:end])
    TimeArray(timestamp,dataarray,colnames[2:end])
end
# function csvtotimearray_adjustclose(url)
#     df = getcsv(url)
#     timestamp = Date[Date(i) for i in df[1]] # parse dates
#     colnames=AbstractString[string(i) for i in DataFrames.names(df)]
#     dataarray=convert(Array, df[[2,3,4,7,6]])
#     TimeArray(timestamp,dataarray,colnames[2:end-1])
# end
function yahoo(symbol, startdate)
    str="a="*string(Dates.month(startdate)-1)*Dates.format(startdate, "&b=dd&c=yyyy")
    url="http://real-chart.finance.yahoo.com/table.csv?s="*symbol*"&"*str*"&g=d&ignore=.csv"
    csvtotimearray(url)
end
function quandl(symbol, startdate)
    str=Dates.format(startdate, "yyyy-mm-dd")
    url="https://www.quandl.com/api/v3/datasets/"*symbol*".csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date="*str
    csvtotimearray(url)
end
# Out:
# WARNING: Method definition getcsv(Any) in module Main at In[2]:3 overwritten at In[232]:3.
# WARNING: Method definition csvtotimearray(Any) in module Main at In[2]:6 overwritten at In[232]:6.
# WARNING: Method definition yahoo(Any, Any) in module Main at In[2]:20 overwritten at In[232]:20.
# WARNING: Method definition quandl(Any, Any) in module Main at In[2]:25 overwritten at In[232]:25.
# quandl (generic function with 1 method)

# %%
symbol="QQQ"
startdate=Date(2007,1,1)
ohlcv=yahoo(symbol, startdate)
# Out:
# 2274x6 TimeSeries.TimeArray{Real,2,DataType} 2007-04-27 to 2016-05-06
#
#              Open      High      Low       Close     Volume          Adj_Close
# 2007-04-27 | 46.37     46.7      46.29     46.57     96536500        42.8906
# 2007-04-30 | 46.49     46.53     45.92     45.96     93290500        42.3288
# 2007-05-01 | 45.97     46.14     45.66     45.92     135044400       42.2919
# 2007-05-02 | 46.09     46.58     46.05     46.42     91971600        42.7524
# ⋮
# 2016-05-03 | 105.96    106.44    105.45    105.73    36351400        105.73
# 2016-05-04 | 105.12    105.48    104.79    105.05    26689000        105.05
# 2016-05-05 | 105.43    105.66    104.81    105.02    20724800        105.02
# 2016-05-06 | 104.5     105.6     104.4     105.58    29731500        105.58

# %%
ta=ohlcv["Close"]
vix=quandl("CBOE/VIX", startdate)
vixarray=TimeArray(vix.timestamp,vix.values[:,end],[vix.colnames[end]])
# Out:
# 2352x1 TimeSeries.TimeArray{Float64,1,DataType} 2007-01-03 to 2016-05-05
#
#              VIX_Close
# 2007-01-03 | 12.04
# 2007-01-04 | 11.51
# 2007-01-05 | 12.14
# 2007-01-08 | 12.0
# ⋮
# 2016-05-02 | 14.68
# 2016-05-03 | 15.6
# 2016-05-04 | 16.05
# 2016-05-05 | 15.91

# %%
ustreasuryarray=quandl("USTREASURY/REALLONGTERM", startdate)
# Out:
# 2341x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-01-02 to 2016-05-06
#
#              LT_Real_Average_10Yrs_
# 2007-01-02 | 2.33
# 2007-01-03 | 2.32
# 2007-01-04 | 2.3
# 2007-01-05 | 2.33
# ⋮
# 2016-05-03 | 0.67
# 2016-05-04 | 0.66
# 2016-05-05 | 0.62
# 2016-05-06 | 0.66

# %%
oil=quandl("EOD/OIL", startdate)
oilarray=TimeArray(oil.timestamp,oil.values[:,end-1],["oil"])
# Out:
# 2353x1 TimeSeries.TimeArray{Float64,1,DataType} 2007-01-03 to 2016-05-06
#
#              oil
# 2007-01-03 | 36.38
# 2007-01-04 | 34.88
# 2007-01-05 | 35.13
# 2007-01-08 | 35.0999
# ⋮
# 2016-05-03 | 5.67
# 2016-05-04 | 5.7
# 2016-05-05 | 5.77
# 2016-05-06 | 5.8

# %%
gold=quandl("WGC/GOLD_DAILY_USD", startdate)
gold2=TimeArray(gold.timestamp,gold.values[:,end],["gold"])
goldarray=gold2./gold2.values[1]
# Out:
# 2440x1 TimeSeries.TimeArray{Float64,1,DataType} 2007-01-01 to 2016-05-06
#
#              gold
# 2007-01-01 | 1.0
# 2007-01-02 | 1.0123
# 2007-01-03 | 1.0168
# 2007-01-04 | 0.9948
# ⋮
# 2016-05-03 | 2.0475
# 2016-05-04 | 2.0301
# 2016-05-05 | 2.0258
# 2016-05-06 | 2.0396

# %%
predictcount=252;
rangelength=28;

# %%
function volumeoscillator(ohlcv, n=28, c="Volume")
    volume=ohlcv[c]
    vshort=ema(volume, Int(n/2))
    vlong=ema(volume, n)
    volumeoscillator=(vshort.-vlong)./vlong
    TimeArray(volumeoscillator.timestamp,volumeoscillator.values,["VolumeOscillator"])
end
# Out:
# WARNING: Method definition volumeoscillator(Any) in module Main at In[239]:2 overwritten at In[276]:2.
# WARNING: Method definition volumeoscillator(Any, Any) in module Main at In[239]:2 overwritten at In[276]:2.
# WARNING: Method definition volumeoscillator(Any, Any, Any) in module Main at In[239]:2 overwritten at In[276]:2.
# volumeoscillator (generic function with 3 methods)

# %%
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close")
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{Real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{Real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr"*string(n)], ohlc.meta)
end
# Out:
# WARNING: Method definition averagetruerange(Any) in module Main at In[240]:2 overwritten at In[277]:2.
# WARNING: Method definition averagetruerange(Any, Any) in module Main at In[240]:2 overwritten at In[277]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any) in module Main at In[240]:2 overwritten at In[277]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any) in module Main at In[240]:2 overwritten at In[277]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any, Any) in module Main at In[240]:2 overwritten at In[277]:2.
# averagetruerange (generic function with 5 methods)

# %%
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    merge(mcd, sig, col_names=["macd", "signal"])
end
# Out:
# WARNING: Method definition macd2(Any) in module Main at In[241]:2 overwritten at In[278]:2.
# WARNING: Method definition macd2(Any, Any) in module Main at In[241]:2 overwritten at In[278]:2.
# WARNING: Method definition macd2(Any, Any, Any) in module Main at In[241]:2 overwritten at In[278]:2.
# WARNING: Method definition macd2(Any, Any, Any, Any) in module Main at In[241]:2 overwritten at In[278]:2.
# macd2 (generic function with 4 methods)

# %%
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pflow=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nflow=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pflow,sum,n)
    nsum=moving(nflow,sum,n)
    flowsum=psum.+nsum
    re=psum./flowsum
    TimeArray(re.timestamp, re.values, ["mfi"], ohlcv.meta)
end
# Out:
# WARNING: Method definition moneyflowindex(Any) in module Main at In[242]:2 overwritten at In[279]:2.
# WARNING: Method definition moneyflowindex(Any, Any) in module Main at In[242]:2 overwritten at In[279]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any) in module Main at In[242]:2 overwritten at In[279]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any) in module Main at In[242]:2 overwritten at In[279]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any) in module Main at In[242]:2 overwritten at In[279]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any, Any) in module Main at In[242]:2 overwritten at In[279]:2.
# moneyflowindex (generic function with 6 methods)

# %%
function chaikinmoneyflow(ohlcv, n=21, h="High", l="Low", c="Close", v="Volume")
    high=ohlcv[h]
    low=ohlcv[l]
    clo=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = (2.*clo.-low.-high)./(high.-low).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf"*string(n)], ohlcv.meta)
end
# Out:
# WARNING: Method definition chaikinmoneyflow(Any) in module Main at In[243]:2 overwritten at In[280]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any) in module Main at In[243]:2 overwritten at In[280]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any) in module Main at In[243]:2 overwritten at In[280]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any) in module Main at In[243]:2 overwritten at In[280]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any) in module Main at In[243]:2 overwritten at In[280]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any, Any) in module Main at In[243]:2 overwritten at In[280]:2.
# chaikinmoneyflow (generic function with 6 methods)

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
# Out:
# WARNING: Method definition overlaps(Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[244]:2 overwritten at In[281]:2.
# overlaps (generic function with 1 method)

# %%
function mergetimearray(ta1, ta2)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, [ta1.colnames; ta2.colnames])
end
# Out:
# WARNING: Method definition mergetimearray(Any, Any) in module Main at In[245]:2 overwritten at In[282]:2.
# mergetimearray (generic function with 1 method)

# %%
function pricerangeindex(ta, n=28)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=mergetimearray(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["pricerange"*string(n)]])
end
# Out:
# WARNING: Method definition pricerangeindex(Any) in module Main at In[246]:2 overwritten at In[283]:2.
# WARNING: Method definition pricerangeindex(Any, Any) in module Main at In[246]:2 overwritten at In[283]:2.
# pricerangeindex (generic function with 2 methods)

# %%
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
# Out:
# WARNING: Method definition bollingerbands2(TimeSeries.TimeArray{#T<:Any, #N<:Any, M<:Any}, Int64, Real) in module Main at In[247]:2 overwritten at In[284]:2.
# bollingerbands2 (generic function with 1 method)

# %%
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=mergetimearray(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev"*string(n)*","*string(width), "bbstd"*string(n)*","*string(width)])
end
# Out:
# WARNING: Method definition bollingerbands_deviation(Any) in module Main at In[248]:2 overwritten at In[285]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any) in module Main at In[248]:2 overwritten at In[285]:2.
# WARNING: Method definition bollingerbands_deviation(Any, Any, Any) in module Main at In[248]:2 overwritten at In[285]:2.
# bollingerbands_deviation (generic function with 3 methods)

# %%
function rsi_mfi_divergence(rsi, mfi, n=14)
    rm=mergetimearray(rsi,mfi)
    div=rsi.-mfi
    signal=ema(div,6)
    r=mergetimearray(div,signal)
    TimeArray(r.timestamp,r.values,["rsi_mfi_div_$n", "rsi_mfi_signal_$n"])
end
# Out:
# WARNING: Method definition rsi_mfi_divergence(Any, Any) in module Main at In[249]:2 overwritten at In[286]:2.
# WARNING: Method definition rsi_mfi_divergence(Any, Any, Any) in module Main at In[249]:2 overwritten at In[286]:2.
# rsi_mfi_divergence (generic function with 2 methods)

# %%
function vwap_divergence(ohlcv, n=28)
    v1=vwap(ohlcv, Int(n/2))
    v2=vwap(ohlcv, n)
    v3=vwap(ohlcv, n*2)
    d1=v1.-v2
    d2=v2.-v3
    div=d1.-d2
    ta=mergetimearray(v1,v2)
    ta=mergetimearray(ta,v3)
    ta=mergetimearray(ta,d1)
    ta=mergetimearray(ta,d2)
    ta=mergetimearray(ta,div)
    cname=["vwap$(Int(n/2))","vwap$n","vwap$(n*2)","vwap$(Int(n/2))-$n","vwap$n-$(n*2)","vwap_2nd_divergence"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition vwap_divergence(Any) in module Main at In[250]:2 overwritten at In[287]:2.
# WARNING: Method definition vwap_divergence(Any, Any) in module Main at In[250]:2 overwritten at In[287]:2.
# vwap_divergence (generic function with 2 methods)

# %%
function atr_divergence(ohlcv, n=28)
    v1=averagetruerange(ohlcv,Int(n/2));
    v2=averagetruerange(ohlcv,n);
    v3=averagetruerange(ohlcv,n*2);
    d1=v1.-v2
    d2=v2.-v3
    div=d1.-d2
    ta=mergetimearray(v1,v2)
    ta=mergetimearray(ta,v3)
    ta=mergetimearray(ta,d1)
    ta=mergetimearray(ta,d2)
    ta=mergetimearray(ta,div)
    cname=["atr$(Int(n/2))","atr$n","atr$(n*2)","atr$(Int(n/2))-$n","atr$n-$(n*2)","atr_2nd_divergence"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition atr_divergence(Any) in module Main at In[252]:2 overwritten at In[288]:2.
# WARNING: Method definition atr_divergence(Any, Any) in module Main at In[252]:2 overwritten at In[288]:2.
# atr_divergence (generic function with 2 methods)

# %%
function rsi_mfi_all(ohlcv, n=14, c="Close")
    ta=ohlcv[c]
    r1=rsi(ta,n)./100
    r2=rsi(ta,n*2)./100
    m1=moneyflowindex(ohlcv,n)
    m2=moneyflowindex(ohlcv,n*2)
    d1=rsi_mfi_divergence(r1,m1,n)
    d2=rsi_mfi_divergence(r2,m2,n*2)
    re=mergetimearray(r2,m2)
    re=mergetimearray(re,r1)
    re=mergetimearray(re,m1)
#     re=mergetimearray(re,d1)
#     re=mergetimearray(re,d2)
end
# Out:
# WARNING: Method definition rsi_mfi_all(Any) in module Main at In[289]:2 overwritten at In[308]:2.
# WARNING: Method definition rsi_mfi_all(Any, Any) in module Main at In[289]:2 overwritten at In[308]:2.
# WARNING: Method definition rsi_mfi_all(Any, Any, Any) in module Main at In[289]:2 overwritten at In[308]:2.
# rsi_mfi_all (generic function with 3 methods)

# %%
rsimfiarray=rsi_mfi_all(ohlcv);

# %%
vwaparray=vwap_divergence(ohlcv, rangelength);
atrarray=atr_divergence(ohlcv, rangelength);

# %%
volumeoscillatorarray=volumeoscillator(ohlcv, rangelength);
macdarray=macd2(ta);
cmfarray=chaikinmoneyflow(ohlcv);
bbarray=bollingerbands_deviation(ta);
rangeindexarray=pricerangeindex(ta, rangelength);

# %%
featurearray=mergetimearray(bbarray,cmfarray)
featurearray=mergetimearray(featurearray,macdarray);
featurearray=mergetimearray(featurearray,volumeoscillatorarray);
featurearray=mergetimearray(featurearray,rsimfiarray);

# %%
featurearray=mergetimearray(featurearray,atrarray);
featurearray=mergetimearray(featurearray,ustreasuryarray);
featurearray=mergetimearray(featurearray,vixarray);
featurearray=mergetimearray(featurearray,vwaparray);
featurearray=mergetimearray(featurearray,goldarray);
featurearray=mergetimearray(featurearray,oilarray);

# %%
withlabel=mergetimearray(featurearray,rangeindexarray)
# Out:
# 2173x30 TimeSeries.TimeArray{Real,2,DataType} 2007-07-18 to 2016-03-30
#
#              bbdev20,2  bbstd20,2  cmf21   macd    signal  VolumeOscillator  rsi     mfi     rsi     mfi     atr14   atr28   atr56   atr14-28  atr28-56  atr_2nd_divergence  LT_Real_Average_10Yrs_  VIX_Close  vwap14    vwap28    vwap56    vwap14-28  vwap28-56  vwap_2nd_divergence  gold    oil      Close     min       max       pricerange28
# 2007-07-18 | 0.824      1.054      0.199   0.762   0.5828  -0.0357           0.7227  0.6903  0.7945  0.8323  0.5121  0.5254  0.5343  -0.0133   -0.0089   -0.0044             2.61                    16.0       48.9629   47.95     47.2815   1.0129     0.6685     0.3443               1.055   41.55    50.17     45.45     50.32     0.9692
# 2007-07-19 | 0.7915     1.0969     0.1295  0.7923  0.6247  -0.0256           0.7328  0.7084  0.8101  0.8374  0.5105  0.5241  0.5335  -0.0136   -0.0094   -0.0042             2.61                    15.23      49.2146   48.1005   47.3543   1.1141     0.7462     0.3679               1.0672  42.05    50.32     45.45     50.32     1.0
# 2007-07-20 | 0.6013     1.1233     0.1858  0.7855  0.6569  0.0103            0.6845  0.6424  0.7     0.7205  0.5183  0.5275  0.535   -0.0092   -0.0075   -0.0017             2.58                    16.95      49.4679   48.2422   47.4506   1.2257     0.7915     0.4342               1.0785  41.94    50.05     45.45     50.07     0.9957
# 2007-07-23 | 0.5538     1.1123     0.1228  0.7728  0.6801  0.0062            0.6861  0.6777  0.7035  0.7032  0.5091  0.5226  0.5325  -0.0135   -0.0098   -0.0036             2.61                    16.81      49.6007   48.3908   47.5076   1.2099     0.8833     0.3266               1.0791  41.39    50.07     45.45     50.07     1.0
# ⋮
# 2016-03-24 | 0.4159     1.5052     0.3623  1.2375  1.1378  -0.1606           0.5952  0.7724  0.6049  0.6462  1.4358  1.7114  1.8181  -0.2756   -0.1066   -0.1689             0.78                    14.74      106.3615  104.6223  102.5112  1.7392     2.1111     -0.3719              1.932   5.3      107.26    105.72    111.23    0.2795
# 2016-03-28 | 0.3278     1.4001     0.3116  1.1715  1.1445  -0.1826           0.586   0.7364  0.5785  0.7255  1.3804  1.6739  1.7974  -0.2934   -0.1235   -0.1699             0.78                    15.24      106.481   104.8825  102.4298  1.5985     2.4527     -0.8542              1.932   5.27     107.11    105.05    111.23    0.3333
# 2016-03-29 | 0.9395     1.2355     0.3907  1.2437  1.1644  -0.1601           0.6525  0.7014  0.7328  0.8479  1.4368  1.6916  1.804   -0.2548   -0.1125   -0.1423             0.67                    13.82      106.8443  105.1521  102.4079  1.6922     2.7442     -1.052               1.9399  5.17     108.83    105.02    111.23    0.6135
# 2016-03-30 | 0.976      1.3694     0.4206  1.3283  1.1972  -0.1554           0.67    0.7293  0.7636  0.8713  1.4206  1.6744  1.7934  -0.2538   -0.119    -0.1347             0.67                    13.56      107.1748  105.467   102.4137  1.7077     3.0534     -1.3456              1.9561  5.12     109.36    105.02    111.23    0.6989

# %%
withoutlabel=mergetimearray(featurearray,ta)
# Out:
# 2199x27 TimeSeries.TimeArray{Real,2,DataType} 2007-07-18 to 2016-05-05
#
#              bbdev20,2  bbstd20,2  cmf21   macd    signal  VolumeOscillator  rsi     mfi     rsi     mfi     atr14   atr28   atr56   atr14-28  atr28-56  atr_2nd_divergence  LT_Real_Average_10Yrs_  VIX_Close  vwap14    vwap28    vwap56    vwap14-28  vwap28-56  vwap_2nd_divergence  gold    oil      Close
# 2007-07-18 | 0.824      1.054      0.199   0.762   0.5828  -0.0357           0.7227  0.6903  0.7945  0.8323  0.5121  0.5254  0.5343  -0.0133   -0.0089   -0.0044             2.61                    16.0       48.9629   47.95     47.2815   1.0129     0.6685     0.3443               1.055   41.55    50.17
# 2007-07-19 | 0.7915     1.0969     0.1295  0.7923  0.6247  -0.0256           0.7328  0.7084  0.8101  0.8374  0.5105  0.5241  0.5335  -0.0136   -0.0094   -0.0042             2.61                    15.23      49.2146   48.1005   47.3543   1.1141     0.7462     0.3679               1.0672  42.05    50.32
# 2007-07-20 | 0.6013     1.1233     0.1858  0.7855  0.6569  0.0103            0.6845  0.6424  0.7     0.7205  0.5183  0.5275  0.535   -0.0092   -0.0075   -0.0017             2.58                    16.95      49.4679   48.2422   47.4506   1.2257     0.7915     0.4342               1.0785  41.94    50.05
# 2007-07-23 | 0.5538     1.1123     0.1228  0.7728  0.6801  0.0062            0.6861  0.6777  0.7035  0.7032  0.5091  0.5226  0.5325  -0.0135   -0.0098   -0.0036             2.61                    16.81      49.6007   48.3908   47.5076   1.2099     0.8833     0.3266               1.0791  41.39    50.07
# ⋮
# 2016-05-02 | -0.777     1.5956     0.0619  -0.2215 0.4258  0.0538            0.419   0.3679  0.3373  0.2222  1.4389  1.5329  1.6656  -0.0941   -0.1327   0.0386              0.68                    14.68      108.6494  108.8207  105.7878  -0.1713    3.0329     -3.2042              2.0343  5.87     106.72
# 2016-05-03 | -0.9378    1.7658     0.0415  -0.3954 0.2616  0.0636            0.3801  0.3613  0.2789  0.0825  1.4268  1.5236  1.6585  -0.0967   -0.135    0.0383              0.67                    15.6       108.2364  108.7107  106.2319  -0.4743    2.4788     -2.9531              2.0475  5.67     105.73
# 2016-05-04 | -0.9642    1.9244     0.0509  -0.5814 0.093   0.0504            0.3557  0.3513  0.2452  0.0756  1.392   1.5027  1.6457  -0.1107   -0.143    0.0323              0.66                    16.05      107.912   108.6142  106.469   -0.7022    2.1452     -2.8474              2.0301  5.7      105.05
# 2016-05-05 | -0.8475    2.0873     -0.0082 -0.7228 -0.0702 0.0263            0.3546  0.3496  0.2437  0.0798  1.3533  1.4794  1.6315  -0.1261   -0.1521   0.026               0.62                    15.91      107.6207  108.5411  106.6128  -0.9204    1.9284     -2.8488              2.0258  5.77     105.02

# %%
dataoffset=length(withoutlabel)-length(withlabel)
lastdate=withlabel.timestamp[end]
lastdateidx=searchsortedfirst(withoutlabel.timestamp, lastdate)
splitidx=lastdateidx-predictcount+dataoffset
newfeatures=TimeArray(withoutlabel.timestamp[splitidx+1:end],withoutlabel.values[splitidx+1:end,:],withoutlabel.colnames);

# %%
training=TimeArray(withlabel.timestamp[1:splitidx],withlabel.values[1:splitidx,:],withlabel.colnames);

# %%
# test=TimeArray(withlabel.timestamp[splitidx+1:end],withlabel.values[splitidx+1:end,:],withlabel.colnames);

# %%
rsiidx=findlast(withlabel.colnames,"rsi")
mfiidx=findlast(withlabel.colnames,"mfi")
closeidx=findfirst(withlabel.colnames,"Close")
# Out:
# 27

# %%
plot(withlabel.timestamp,withlabel.values[:,1:closeidx])
legend(withlabel.colnames[1:closeidx],bbox_to_anchor=(1.52, 1.02))
title("Features for training")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6b16b45250>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
using DecisionTree
using ScikitLearn
ntrees=100
pricerangeidx=closeidx+3
features=training.values[:,1:closeidx]
labels=convert(Array{Float64,1},training.values[:,pricerangeidx])
model = build_forest(labels,features, 2, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 460.97
# Avg Depth:  23.8

# %%
newlabels=apply_forest(model, newfeatures.values);

# %%
initvalue=withlabel.values[1,closeidx];

# %%
plot(withoutlabel.timestamp,withoutlabel.values[:,closeidx]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,closeidx+1:closeidx+2]./initvalue)
plot(training.timestamp,training.values[:,pricerangeidx],c="k")
plot(withlabel.timestamp,withlabel.values[:,rsiidx],c="c")
plot(withlabel.timestamp,withlabel.values[:,mfiidx],c="y")
plot(newfeatures.timestamp,newlabels,c="DimGrey",linewidth=1.5)
title(symbol*" history & forecast")
grid("on")
legend([withlabel.colnames[[closeidx,closeidx+1,closeidx+2,pricerangeidx,rsiidx,mfiidx]];"price range forecast"],bbox_to_anchor=(1.46, 1.02))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6b16bb8050>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue,c="b")
plot(newfeatures.timestamp,newfeatures.values[:,rsiidx],c="c")
plot(newfeatures.timestamp,newfeatures.values[:,mfiidx],c="y")
plot(newfeatures.timestamp,newlabels,c="DimGrey",linewidth=1.5)
legend([newfeatures.colnames[[closeidx,rsiidx,mfiidx]];"price range forecast"],bbox_to_anchor=(1.46, 1.02))
title(symbol*" forecast: random forest with "*string(ntrees)*" trees"*", period="*string(rangelength))
grid("on")
# color names http://astropython.blogspot.ie/2012/02/additional-color-names-for-matplotlib.html
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6b16b015d0>)

# %%
features=withlabel.values[:,1:closeidx]
labels=convert(Array{Float64,1},withlabel.values[:,pricerangeidx])
# run n-fold cross validation on regression forest
# using 2 random features, 10 trees, 3 folds, averaging of 5 samples/leaf (optional),
# and 0.7 porition of samples per tree (optional)
# returns array of coefficients of determination (R^2)
r2 = nfoldCV_forest(labels, features, 2, ntrees, 3, 5, 0.7)
# Out:
# Fold 1
# Mean Squared Error:     0.034623180625582395
# Correlation Coeff:      0.8960158911544056
# Coeff of Determination: 0.7138680648885449
#
# Fold 2
# Mean Squared Error:     0.032621057531044786
# Correlation Coeff:      0.912091083315768
# Coeff of Determination: 0.7250511463096451
#
# Fold 3
# 3-element Array{Float64,1}:
#  0.713868
#  0.725051
#  0.719149
# Mean Squared Error:     0.03343889177232751
# Correlation Coeff:      0.9032348461078543
# Coeff of Determination: 0.7191494071217978
#
# Mean Coeff of Determination: 0.7193562061066626
