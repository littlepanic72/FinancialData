# %%
using DataFrames
using Requests
using TimeSeries
using MarketTechnicals
using PyPlot

# %%
function getcsv(url)
    df = readtable(Requests.get_streaming(url))
end
function csvtotimearray(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    dataarray=convert(Array, df[2:end])
    TimeArray(timestamp,dataarray,colnames[2:end])
end
function yahoo(symbol, startdate)
    str="a=$(Dates.month(startdate)-1)"*Dates.format(startdate, "&b=dd&c=yyyy")
    url="http://real-chart.finance.yahoo.com/table.csv?s="*symbol*"&"*str*"&g=d&ignore=.csv"
    csvtotimearray(url)
end
function quandl(symbol, startdate)
    str=Dates.format(startdate, "yyyy-mm-dd")
    url="https://www.quandl.com/api/v3/datasets/$symbol.csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date=$str"
    csvtotimearray(url)
end
# Out:
# WARNING: Method definition getcsv(Any) in module Main at In[2]:2 overwritten at In[47]:2.
# WARNING: Method definition csvtotimearray(Any) in module Main at In[2]:5 overwritten at In[47]:5.
# WARNING: Method definition yahoo(Any, Any) in module Main at In[2]:12 overwritten at In[47]:12.
# WARNING: Method definition quandl(Any, Any) in module Main at In[2]:17 overwritten at In[47]:17.
# quandl (generic function with 1 method)

# %%
startdate=Date(2007,11,1) # set an early date to make use of all CBOE/GVZ data
symbol="QQQ"
ohlcv=yahoo(symbol, startdate)
# Out:
# 2145x6 TimeSeries.TimeArray{Real,2,DataType} 2007-11-01 to 2016-05-10
#
#              Open      High      Low       Close     Volume          Adj_Close
# 2007-11-01 | 54.68     54.77     53.97     54.0      181974200       49.7983
# 2007-11-02 | 54.42     54.55     53.6      54.42     217882900       50.1856
# 2007-11-05 | 53.86     54.4      53.59     54.07     150588900       49.8629
# 2007-11-06 | 54.33     54.69     53.78     54.68     131884700       50.4254
# ⋮
# 2016-05-05 | 105.43    105.66    104.81    105.02    20724800        105.02
# 2016-05-06 | 104.5     105.6     104.4     105.58    29731500        105.58
# 2016-05-09 | 105.59    106.37    105.54    105.88    18852100        105.88
# 2016-05-10 | 106.26    107.38    106.07    107.33    21013500        107.33

# %%
vix=quandl("CBOE/VIX", startdate)
vixarray=TimeArray(vix.timestamp,vix.values[:,end],["CBOE/VIX"])
# Out:
# 2145x1 TimeSeries.TimeArray{Float64,1,DataType} 2007-11-01 to 2016-05-10
#
#              CBOE/VIX
# 2007-11-01 | 23.21
# 2007-11-02 | 23.01
# 2007-11-05 | 24.31
# 2007-11-06 | 21.39
# ⋮
# 2016-05-05 | 15.91
# 2016-05-06 | 14.72
# 2016-05-09 | 14.57
# 2016-05-10 | 13.63

# %%
vxn=quandl("CBOE/VXN", startdate)
vxnarray=TimeArray(vxn.timestamp,vxn.values[:,end],["CBOE/VXN"])
# Out:
# 2145x1 TimeSeries.TimeArray{Float64,1,DataType} 2007-11-01 to 2016-05-10
#
#              CBOE/VXN
# 2007-11-01 | 26.26
# 2007-11-02 | 24.83
# 2007-11-05 | 26.1
# 2007-11-06 | 23.91
# ⋮
# 2016-05-05 | 19.14
# 2016-05-06 | 17.54
# 2016-05-09 | 17.38
# 2016-05-10 | 16.27

# %%
ovx=quandl("CBOE/OVX", startdate) # CBOE/OVX since 2007-05-10
ovxarray=TimeArray(ovx.timestamp,ovx.values,["CBOE/OVX"])
# Out:
# 2146x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-10
#
#              CBOE/OVX
# 2007-11-01 | 39.71
# 2007-11-02 | 39.99
# 2007-11-05 | 40.14
# 2007-11-06 | 41.2
# ⋮
# 2016-05-05 | 44.82
# 2016-05-06 | 42.47
# 2016-05-09 | 44.14
# 2016-05-10 | 42.28

# %%
evz=quandl("CBOE/EVZ", startdate) # CBOE/EVZ since 2007-11-01
evzarray=TimeArray(evz.timestamp,evz.values,["CBOE/EVZ"])
# Out:
# 2138x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-10
#
#              CBOE/EVZ
# 2007-11-01 | 8.09
# 2007-11-02 | 8.12
# 2007-11-05 | 7.98
# 2007-11-06 | 8.18
# ⋮
# 2016-05-05 | 10.2
# 2016-05-06 | 9.52
# 2016-05-09 | 9.41
# 2016-05-10 | 9.22

# %%
gvz=quandl("CBOE/GVZ", startdate) # CBOE/GVZ since 2008-6-3
gvzarray=TimeArray(gvz.timestamp,gvz.values,["CBOE/GVZ"])
# Out:
# 2000x1 TimeSeries.TimeArray{Float64,2,DataType} 2008-06-03 to 2016-05-10
#
#              CBOE/GVZ
# 2008-06-03 | 22.89
# 2008-06-04 | 22.69
# 2008-06-05 | 22.78
# 2008-06-06 | 23.6
# ⋮
# 2016-05-05 | 18.46
# 2016-05-06 | 18.65
# 2016-05-09 | 18.65
# 2016-05-10 | 18.04

# %%
eurusd=quandl("ECB/EURUSD", startdate)
eurusdarray=TimeArray(eurusd.timestamp,eurusd.values,["ECB/EURUSD"])
# Out:
# 2181x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-11
#
#              ECB/EURUSD
# 2007-11-01 | 1.4423
# 2007-11-02 | 1.4479
# 2007-11-05 | 1.4488
# 2007-11-06 | 1.4547
# ⋮
# 2016-05-06 | 1.1427
# 2016-05-09 | 1.1395
# 2016-05-10 | 1.1375
# 2016-05-11 | 1.1409

# %%
ustreasury=quandl("USTREASURY/REALLONGTERM", startdate)
ustreasuryarray=TimeArray(ustreasury.timestamp,ustreasury.values,["USTREASURY/REALLONGTERM"])
# Out:
# LoadError: Saw 481 rows, 1 columns and 961 fields
#  * Line 1 has 4 columns
#
# while loading In[55], in expression starting on line 1
#
#  in error(::ASCIIString) at ./error.jl:21
#  in findcorruption(::Int64, ::Int64, ::Int64, ::DataFrames.ParsedCSV) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:722
#  in readtable!(::DataFrames.ParsedCSV, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64, ::DataFrames.ParseOptions{ASCIIString}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:793
#  in #readtable#26(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{ASCIIString,1}, ::Array{ASCIIString,1}, ::Array{ASCIIString,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{DataType,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:862
#  [inlined code] from ./boot.jl:307
#  in csvtotimearray(::ASCIIString) at ./In[47]:5
#  in quandl(::ASCIIString, ::Date) at ./In[47]:19
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371

# %%
ushybond=quandl("ML/HYOAS", startdate)
ushybondarray=TimeArray(ushybond.timestamp,ushybond.values,["ML/HYOAS"])
# Out:
# 2224x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-10
#
#              ML/HYOAS
# 2007-11-01 | 4.53
# 2007-11-02 | 4.65
# 2007-11-05 | 4.69
# 2007-11-06 | 4.66
# ⋮
# 2016-05-05 | 6.42
# 2016-05-06 | 6.48
# 2016-05-09 | 6.53
# 2016-05-10 | 6.46

# %%
usaabond=quandl("ML/AAOAS", startdate)
usaabondarray=TimeArray(usaabond.timestamp,usaabond.values,["ML/AAOAS"])
# Out:
# 2224x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-10
#
#              ML/AAOAS
# 2007-11-01 | 1.29
# 2007-11-02 | 1.34
# 2007-11-05 | 1.41
# 2007-11-06 | 1.42
# ⋮
# 2016-05-05 | 0.86
# 2016-05-06 | 0.87
# 2016-05-09 | 0.87
# 2016-05-10 | 0.88

# %%
usyieldspread=ushybondarray.-usaabondarray;
usyieldspreadarray=TimeArray(usyieldspread.timestamp,usyieldspread.values,["ML/HYOAS-ML/AAOAS"]);

# %%
oil=quandl("OPEC/ORB", startdate)
oilarray=TimeArray(oil.timestamp,oil.values,["OPEC/ORB"])
# Out:
# 2199x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-10
#
#              OPEC/ORB
# 2007-11-01 | 87.47
# 2007-11-02 | 87.47
# 2007-11-05 | 88.0
# 2007-11-06 | 89.02
# ⋮
# 2016-05-05 | 41.15
# 2016-05-06 | 40.55
# 2016-05-09 | 40.76
# 2016-05-10 | 40.2

# %%
gold=quandl("WGC/GOLD_DAILY_USD", startdate)
goldarray=TimeArray(gold.timestamp,gold.values./gold.values[1],["WGC/GOLD_DAILY_USD"])
# Out:
# 2225x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-11
#
#              WGC/GOLD_DAILY_USD
# 2007-11-01 | 1.0
# 2007-11-02 | 1.0079
# 2007-11-05 | 1.0184
# 2007-11-06 | 1.0408
# ⋮
# 2016-05-06 | 1.6311
# 2016-05-09 | 1.6011
# 2016-05-10 | 1.598
# 2016-05-11 | 1.6158

# %%
ta=ohlcv["Close"];
predictcount=252;
rangelength=32;

# %%
function aroon(ta, n=25)
    up=moving(ta,x->findlast(x,maximum(x))/length(x),n)
    down=moving(ta,x->findlast(x,minimum(x))/length(x),n)
    d=up.-down
    r=merge2(up,down)
    r=merge2(r,d)
    TimeArray(r.timestamp,r.values,["aroon$n.up","aroon$n.down","aroon$n.up-down"])
end
# Out:
# WARNING: Method definition aroon(Any) in module Main at In[17]:2 overwritten at In[62]:2.
# WARNING: Method definition aroon(Any, Any) in module Main at In[17]:2 overwritten at In[62]:2.
# aroon (generic function with 2 methods)

# %%
function volumeoscillator(ohlcv, n=28, c="Volume")
    volume=ohlcv[c]
    vshort=ema(volume, int(n/2))
    vlong=ema(volume, n)
    volumeoscillator=(vshort.-vlong)./vlong
    TimeArray(volumeoscillator.timestamp,volumeoscillator.values,["VolumeOscillator$n"])
end
# function volumeoscillator_all(ohlcv, n=28)
#     v0=volumeoscillator(ohlcv, Int(n/2))
#     v1=volumeoscillator(ohlcv, n)
#     v2=volumeoscillator(ohlcv, n*2)
#     r=merge2(v0,v1)
#     merge2(r,v2)
# end
# Out:
# WARNING: Method definition volumeoscillator(Any) in module Main at In[18]:2 overwritten at In[63]:2.
# WARNING: Method definition volumeoscillator(Any, Any) in module Main at In[18]:2 overwritten at In[63]:2.
# WARNING: Method definition volumeoscillator(Any, Any, Any) in module Main at In[18]:2 overwritten at In[63]:2.
# volumeoscillator (generic function with 3 methods)

# %%
function chaikinmoneyflow(ohlcv, n=21, h="High", l="Low", c="Close", v="Volume")
    high=ohlcv[h]
    low=ohlcv[l]
    clo=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = (2.*clo.-low.-high)./(high.-low).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf$n"], ohlcv.meta)
end
# Out:
# WARNING: Method definition chaikinmoneyflow(Any) in module Main at In[19]:2 overwritten at In[64]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any) in module Main at In[19]:2 overwritten at In[64]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any) in module Main at In[19]:2 overwritten at In[64]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any) in module Main at In[19]:2 overwritten at In[64]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any) in module Main at In[19]:2 overwritten at In[64]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any, Any) in module Main at In[19]:2 overwritten at In[64]:2.
# chaikinmoneyflow (generic function with 6 methods)

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
function merge2(ta1, ta2)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, [ta1.colnames; ta2.colnames])
end
# Out:
# WARNING: Method definition overlaps(Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[20]:2 overwritten at In[65]:2.
# WARNING: Method definition merge2(Any, Any) in module Main at In[20]:20 overwritten at In[65]:20.
# merge2 (generic function with 1 method)

# %%
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=merge2(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev$n,$width", "bbstd$n,$width"])
end
function bollingerbands_all(ta, n=20, width=2)
    b0=bollingerbands_deviation(ta, int(n/2), width)
    b1=bollingerbands_deviation(ta, n, width)
    b2=bollingerbands_deviation(ta, n*2, width)
    r=merge2(b0,b1)
    merge2(b1,b2)
end
# Out:
# WARNING: Method definition bollingerbands2(TimeSeries.TimeArray{#T<:Any, #N<:Any, M<:Any}, Int64, Real) in module Main at In[21]:2 overwritten at In[66]:2.
# WARNING: Method definition bollingerbands_deviation(Any) in module Main at In[21]:9 overwritten at In[66]:9.
# WARNING: Method definition bollingerbands_deviation(Any, Any) in module Main at In[21]:9 overwritten at In[66]:9.
# WARNING: Method definition bollingerbands_deviation(Any, Any, Any) in module Main at In[21]:9 overwritten at In[66]:9.
# WARNING: Method definition bollingerbands_all(Any) in module Main at In[21]:16 overwritten at In[66]:16.
# WARNING: Method definition bollingerbands_all(Any, Any) in module Main at In[21]:16 overwritten at In[66]:16.
# WARNING: Method definition bollingerbands_all(Any, Any, Any) in module Main at In[21]:16 overwritten at In[66]:16.
# bollingerbands_all (generic function with 3 methods)

# %%
function vwap_divergence(ohlcv, n=28)
    v1=vwap(ohlcv, int(n/2))
    v2=vwap(ohlcv, n)
    v3=vwap(ohlcv, n*2)
    v4=vwap(ohlcv, n*4)
#     v5=vwap(ohlcv, n*8)
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
#     d4=v4.-v5
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
#     ta=merge2(ta,v5)
#     ta=merge2(ta,d4)
    cname=["vwap$(Int(n/2))","vwap$n","vwap$(n*2)","vwap$(n*4)","vwap$(Int(n/2))-$n","vwap$n-$(n*2)","vwap$(n*2)-$(n*4)"]#,"vwap$(n*8)","vwap$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition vwap_divergence(Any) in module Main at In[22]:2 overwritten at In[67]:2.
# WARNING: Method definition vwap_divergence(Any, Any) in module Main at In[22]:2 overwritten at In[67]:2.
# vwap_divergence (generic function with 2 methods)

# %%
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close")
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{Real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{Real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr$n"], ohlc.meta)
end
function atr_divergence(ohlcv, n=28)
    v1=averagetruerange(ohlcv,Int(n/2));
    v2=averagetruerange(ohlcv,n);
    v3=averagetruerange(ohlcv,n*2);
    v4=averagetruerange(ohlcv,n*4);
#     v5=averagetruerange(ohlcv,n*8);
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
#     d4=v4.-v5
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
#     ta=merge2(ta,v5)
#     ta=merge2(ta,d4)
    cname=["atr$(Int(n/2))","atr$n","atr$(n*2)","atr$(n*4)","atr$(Int(n/2))-$n","atr$n-$(n*2)","atr$(n*2)-$(n*4)"]#,"atr$(n*8)","atr$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition averagetruerange(Any) in module Main at In[23]:2 overwritten at In[68]:2.
# WARNING: Method definition averagetruerange(Any, Any) in module Main at In[23]:2 overwritten at In[68]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any) in module Main at In[23]:2 overwritten at In[68]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any) in module Main at In[23]:2 overwritten at In[68]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any, Any) in module Main at In[23]:2 overwritten at In[68]:2.
# WARNING: Method definition atr_divergence(Any) in module Main at In[23]:12 overwritten at In[68]:12.
# WARNING: Method definition atr_divergence(Any, Any) in module Main at In[23]:12 overwritten at In[68]:12.
# atr_divergence (generic function with 2 methods)

# %%
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pflow=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nflow=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pflow,sum,n)
    nsum=moving(nflow,sum,n)
    flowsum=psum.+nsum
    re=psum./flowsum
    TimeArray(re.timestamp, re.values, ["mfi$n"], ohlcv.meta)
end
function rsi_mfi_divergence(rsi, mfi, n=14)
    signal=ema(mfi.-rsi,5)
    TimeArray(signal.timestamp,signal.values,["rsi_mfi_divergence"])
end
function rsi_mfi_all(ohlcv, n=28, c="Close")
    ta=ohlcv[c]
    n0=int(n/2)
    r0=rsi(ta,n0)./100
    r1=rsi(ta,n)./100
    m0=moneyflowindex(ohlcv,n0)
    m1=moneyflowindex(ohlcv,n)
    re=merge2(r0,m0)
    re=merge2(re,r1)
    re=merge2(re,m1)
end
# Out:
# WARNING: Method definition moneyflowindex(Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition moneyflowindex(Any, Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any, Any) in module Main at In[24]:2 overwritten at In[69]:2.
# WARNING: Method definition rsi_mfi_divergence(Any, Any) in module Main at In[24]:19 overwritten at In[69]:19.
# WARNING: Method definition rsi_mfi_divergence(Any, Any, Any) in module Main at In[24]:19 overwritten at In[69]:19.
# WARNING: Method definition rsi_mfi_all(Any) in module Main at In[24]:23 overwritten at In[69]:23.
# WARNING: Method definition rsi_mfi_all(Any, Any) in module Main at In[24]:23 overwritten at In[69]:23.
# WARNING: Method definition rsi_mfi_all(Any, Any, Any) in module Main at In[24]:23 overwritten at In[69]:23.
# rsi_mfi_all (generic function with 3 methods)

# %%
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    r = merge(mcd, sig, col_names=["macd($fast,$slow,$signal)", "signal"])
#     merge(r, mcd .- sig, col_names=[r.colnames; ["histogram"]])
end
# Out:
# WARNING: Method definition macd2(Any) in module Main at In[25]:2 overwritten at In[70]:2.
# WARNING: Method definition macd2(Any, Any) in module Main at In[25]:2 overwritten at In[70]:2.
# WARNING: Method definition macd2(Any, Any, Any) in module Main at In[25]:2 overwritten at In[70]:2.
# WARNING: Method definition macd2(Any, Any, Any, Any) in module Main at In[25]:2 overwritten at In[70]:2.
# macd2 (generic function with 4 methods)

# %%
function priceindex(ta, n=28)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=merge2(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["priceindex$n"]])
end
# Out:
# WARNING: Method definition priceindex(Any) in module Main at In[26]:2 overwritten at In[71]:2.
# WARNING: Method definition priceindex(Any, Any) in module Main at In[26]:2 overwritten at In[71]:2.
# priceindex (generic function with 2 methods)

# %%
rsimfiarray=rsi_mfi_all(ohlcv,rangelength);
vwaparray=vwap_divergence(ohlcv,rangelength);
atrarray=atr_divergence(ohlcv,rangelength);
aroonarray=aroon(ta,rangelength);
volumeoscillatorarray=volumeoscillator(ohlcv,rangelength);
macdarray=macd2(ta,int(rangelength/2),rangelength);
cmfarray=chaikinmoneyflow(ohlcv,rangelength);
bbarray=bollingerbands_all(ta,rangelength,2);
priceindexarray=priceindex(ta,rangelength);
# Out:
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in rsi_mfi_all(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64, ::ASCIIString) at ./In[69]:24
#  in rsi_mfi_all(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[69]:23
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[72], in expression starting on line 1
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in vwap_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[67]:2
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[72], in expression starting on line 2
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in volumeoscillator(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64, ::ASCIIString) at ./In[63]:3
#  in volumeoscillator(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[63]:2
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[72], in expression starting on line 5
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.

# %%
featurearray=merge2(bbarray,cmfarray);
featurearray=merge2(featurearray,macdarray);
featurearray=merge2(featurearray,volumeoscillatorarray);
featurearray=merge2(featurearray,rsimfiarray);
featurearray=merge2(featurearray,atrarray);
featurearray=merge2(featurearray,vwaparray);
featurearray=merge2(featurearray,aroonarray);
featurearray=merge2(featurearray,ustreasuryarray);
featurearray=merge2(featurearray,ushybondarray);
featurearray=merge2(featurearray,usaabondarray);
featurearray=merge2(featurearray,usyieldspreadarray);
featurearray=merge2(featurearray,vixarray);
featurearray=merge2(featurearray,vxnarray);
featurearray=merge2(featurearray,goldarray);
featurearray=merge2(featurearray,gvzarray);
featurearray=merge2(featurearray,oilarray);
featurearray=merge2(featurearray,ovxarray);
featurearray=merge2(featurearray,eurusdarray);
featurearray=merge2(featurearray,evzarray);
# Out:
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in bollingerbands_all(::TimeSeries.TimeArray{Real,1,DataType}, ::Int64, ::Int64) at ./In[66]:16
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[72], in expression starting on line 8

# %%
withlabel=merge2(featurearray,priceindexarray)
# Out:
# 1933x45 TimeSeries.TimeArray{Real,2,DataType} 2008-06-03 to 2016-03-24
#
#              bbdev32,2  bbstd32,2  bbdev64,2  bbstd64,2  cmf32   macd(16,32,9)  signal  VolumeOscillator32  rsi     mfi16   rsi     mfi32   atr16   atr32   atr64   atr128  atr16-32  atr32-64  atr64-128  vwap16    vwap32    vwap64    vwap128   vwap16-32  vwap32-64  vwap64-128  aroon32.up  aroon32.down  aroon32.up-down  USTREASURY/REALLONGTERM  ML/HYOAS  ML/AAOAS  ML/HYOAS-ML/AAOAS  CBOE/VIX  CBOE/VXN  WGC/GOLD_DAILY_USD  CBOE/GVZ  OPEC/ORB  CBOE/OVX
# 2016-05-06 | -0.8003    1.8763     -0.0442    3.9185     0.0749  -0.3769        0.1506  0.0136              0.3369  0.0823  0.4077  0.3419  1.3589  1.502   1.6431  1.6461  -0.1432   -0.1411   -0.003     107.6277  108.3457  104.4829  106.4839  -0.718     3.8628     -2.001      0.5625      0.9688        -0.4062          0.66                     6.48      0.87      5.61               14.72     17.54     1.6311              18.65     40.55     42.47     1.1427      9.52      105.58
# 2016-05-09 | -0.6926    1.9209     -0.0221    3.7932     0.0842  -0.4273        0.035   -0.0074             0.3755  0.1259  0.4239  0.3669  1.3258  1.481   1.6304  1.6397  -0.1552   -0.1494   -0.0093    107.4141  108.3173  104.7222  106.4434  -0.9032    3.5951     -1.7212     0.5312      0.9375        -0.4062          0.66                     6.53      0.87      5.66               14.57     17.38     1.6011              18.65     40.76     44.14     1.1395      9.41      105.88
# 2016-05-10 | -0.316     1.9194     0.1546     3.6051     0.0863  -0.3834        -0.0487 -0.0208             0.5264  0.1737  0.4953  0.3976  1.3367  1.4816  1.6284  1.6386  -0.1449   -0.1468   -0.0102    107.2714  108.3165  105.1375  106.3939  -1.0451    3.179      -1.2564     0.5         0.9062        -0.4062          0.63                     6.46      0.88      5.58               13.63     16.27     1.598               18.04     40.2      42.28     1.1375      9.22      107.33

# %%
dataoffset=length(withoutlabel)-length(withlabel)
lastdate=withlabel.timestamp[end]
lastdateidx=searchsortedfirst(withoutlabel.timestamp, lastdate)
splitidx=lastdateidx-predictcount+dataoffset
newfeatures=TimeArray(withoutlabel.timestamp[splitidx+1:end],withoutlabel.values[splitidx+1:end,:],withoutlabel.colnames);

# %%
training=TimeArray(withlabel.timestamp[1:splitidx],withlabel.values[1:splitidx,:],withlabel.colnames);

# %%
test=TimeArray(withlabel.timestamp[splitidx+1:end],withlabel.values[splitidx+1:end,:],withlabel.colnames);

# %%
rsiidx=findfirst(withlabel.colnames,"rsi")
rsiidx2=findlast(withlabel.colnames,"rsi")
mfiidx=findfirst(withlabel.colnames,"mfi$rangelength")
pricerangeidx=findfirst(withlabel.colnames,"priceindex$rangelength")
closeidx=findfirst(withlabel.colnames,"Close")
# Out:
# 42

# %%
randomfeaturenum=int(sqrt(closeidx))
# Out:
# 6

# %%
plot(withlabel.timestamp,withlabel.values[:,1:closeidx])
legend(withlabel.colnames[1:closeidx],bbox_to_anchor=(1.62, 1.02))
title("Features for training")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f80f7b1f090>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
using DecisionTree
ntrees=100
features=training.values[:,1:closeidx]
labels=convert(Array{Float64,1},training.values[:,pricerangeidx])
# train regression forest, using 2 random features, 10 trees,
# averaging of 5 samples per leaf (optional), 0.7 of samples per tree (optional)
model = build_forest(labels, features, randomfeaturenum, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 421.41
# Avg Depth:  27.02

# %%
newlabels=apply_forest(model, newfeatures.values);
initvalue=withlabel.values[1,closeidx];

# %%
plot(withoutlabel.timestamp,withoutlabel.values[:,closeidx]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,closeidx+1:closeidx+2]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,rsiidx2],c="c")
plot(withlabel.timestamp,withlabel.values[:,mfiidx],c="DarkOrange")
plot(training.timestamp,training.values[:,pricerangeidx],c="DimGrey")
plot(newfeatures.timestamp,newlabels,c="k")
title("$symbol history & forecast")
grid("on")
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
legend([withlabel.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx2,mfiidx,pricerangeidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f80f67b4390>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue)
plot(test.timestamp,test.values[:,closeidx+1:closeidx+2]./initvalue)
plot(newfeatures.timestamp,newfeatures.values[:,rsiidx2],c="c")
plot(newfeatures.timestamp,newfeatures.values[:,mfiidx],c="DarkOrange")
plot(test.timestamp,test.values[:,pricerangeidx],c="DimGrey")
plot(newfeatures.timestamp,newlabels,c="k")
legend([test.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx2,mfiidx,pricerangeidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
title("$symbol forecast: random forest with $ntrees trees, period=$rangelength")
grid("on")
# color names http://astropython.blogspot.ie/2012/02/additional-color-names-for-matplotlib.html
# http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.axhline
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f80f68d0450>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
features=withlabel.values[:,1:closeidx]
labels=convert(Array{Float64,1},withlabel.values[:,pricerangeidx])
# run n-fold cross validation on regression forest
# using 2 random features, 10 trees, 3 folds, averaging of 5 samples/leaf (optional),
# and 0.7 porition of samples per tree (optional)
# returns array of coefficients of determination (R^2)
r2 = nfoldCV_forest(labels, features, 2, ntrees, 3, 5, 0.7)
# Out:
# Fold 1
# Mean Squared Error:     0.022331986892246355
# Correlation Coeff:      0.9273630132017671
# Coeff of Determination: 0.7978190103839621
#
# Fold 2
# Mean Squared Error:     0.025899096935367204
# Correlation Coeff:      0.9294089727570591
# Coeff of Determination: 0.78438984556617
#
# Fold 3
# 3-element Array{Float64,1}:
#  0.797819
#  0.78439
#  0.790092
# Mean Squared Error:     0.024513820238145533
# Correlation Coeff:      0.9285605684836152
# Coeff of Determination: 0.7900915825083474
#
# Mean Coeff of Determination: 0.7907668128194931
