# %%
using DataFrames
using Requests
using TimeSeries
using MarketTechnicals
using PyPlot

# %%
function getcsv(url)
    df = readtable(Requests.get_streaming(url))
end
function csvtotimearray(url)
    df = getcsv(url)
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=AbstractString[string(i) for i in DataFrames.names(df)]
    dataarray=convert(Array, df[2:end])
    TimeArray(timestamp,dataarray,colnames[2:end])
end
function yahoo(symbol, startdate)
    str="a=$(Dates.month(startdate)-1)"*Dates.format(startdate, "&b=dd&c=yyyy")
    url="http://real-chart.finance.yahoo.com/table.csv?s="*symbol*"&"*str*"&g=d&ignore=.csv"
    csvtotimearray(url)
end
function quandl(symbol, startdate)
    str=Dates.format(startdate, "yyyy-mm-dd")
    url="https://www.quandl.com/api/v3/datasets/$symbol.csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date=$str"
    csvtotimearray(url)
end
# extend a 1D series with its last element
function padseries(short, long, columns=Void)
    times=long.timestamp[searchsortedfirst(long.timestamp,short.timestamp[end])+1:end]
    TimeArray([short.timestamp;times], [short.values;fill(short.values[end], length(times))], columns==Void?short.colnames:columns)
end
# Out:
# WARNING: Method definition getcsv(Any) in module Main at In[380]:2 overwritten at In[382]:2.
# WARNING: Method definition csvtotimearray(Any) in module Main at In[380]:5 overwritten at In[382]:5.
# WARNING: Method definition yahoo(Any, Any) in module Main at In[380]:12 overwritten at In[382]:12.
# WARNING: Method definition quandl(Any, Any) in module Main at In[380]:17 overwritten at In[382]:17.
# WARNING: Method definition padseries(Any, Any) in module Main at In[380]:23 overwritten at In[382]:23.
# WARNING: Method definition padseries(Any, Any, Any) in module Main at In[380]:23 overwritten at In[382]:23.
# padseries (generic function with 2 methods)

# %%
startdate=Date(2007,11,1) # set an early date to make use of all CBOE/GVZ data
symbol="QQQ"
ohlcv=yahoo(symbol, startdate)
# Out:
# 2149x6 TimeSeries.TimeArray{Real,2,DataType} 2007-11-01 to 2016-05-16
#
#              Open      High      Low       Close     Volume          Adj_Close
# 2007-11-01 | 54.68     54.77     53.97     54.0      181974200       49.7983
# 2007-11-02 | 54.42     54.55     53.6      54.42     217882900       50.1856
# 2007-11-05 | 53.86     54.4      53.59     54.07     150588900       49.8629
# 2007-11-06 | 54.33     54.69     53.78     54.68     131884700       50.4254
# ⋮
# 2016-05-11 | 107.17    107.49    106.33    106.36    20883000        106.36
# 2016-05-12 | 106.61    106.74    105.14    105.89    29120600        105.89
# 2016-05-13 | 105.85    106.45    105.29    105.5     21036800        105.5
# 2016-05-16 | 105.66    107.21    105.56    106.82    18281600        106.82

# %%
eurusd=quandl("ECB/EURUSD", startdate)
eurusdarray=TimeArray(eurusd.timestamp,eurusd.values,["ECB/EURUSD"])
# Out:
# 2184x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              ECB/EURUSD
# 2007-11-01 | 1.4423
# 2007-11-02 | 1.4479
# 2007-11-05 | 1.4488
# 2007-11-06 | 1.4547
# ⋮
# 2016-05-11 | 1.1409
# 2016-05-12 | 1.1389
# 2016-05-13 | 1.1348
# 2016-05-16 | 1.1324

# %%
gold=quandl("WGC/GOLD_DAILY_USD", startdate)
goldarray=TimeArray(gold.timestamp,gold.values./gold.values[1],["WGC/GOLD_DAILY_USD"])
# Out:
# 2228x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              WGC/GOLD_DAILY_USD
# 2007-11-01 | 1.0
# 2007-11-02 | 1.0079
# 2007-11-05 | 1.0184
# 2007-11-06 | 1.0408
# ⋮
# 2016-05-11 | 1.6158
# 2016-05-12 | 1.6189
# 2016-05-13 | 1.6019
# 2016-05-16 | 1.6271

# %%
ustreasury=quandl("USTREASURY/REALLONGTERM", startdate)
ustreasuryarray=TimeArray(ustreasury.timestamp,ustreasury.values,["USTREASURY/REALLONGTERM"])
# Out:
# 2136x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              USTREASURY/REALLONGTERM
# 2007-11-01 | 2.12
# 2007-11-02 | 2.05
# 2007-11-05 | 2.06
# 2007-11-06 | 2.07
# ⋮
# 2016-05-11 | 0.62
# 2016-05-12 | 0.63
# 2016-05-13 | 0.6
# 2016-05-16 | 0.62

# %%
vix=quandl("CBOE/VIX", startdate)
# Out:
# 2149x4 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              VIX_Open  VIX_High  VIX_Low  VIX_Close
# 2007-11-01 | 19.89     24.15     17.38    23.21
# 2007-11-02 | 22.56     25.17     22.56    23.01
# 2007-11-05 | 25.25     25.46     23.61    24.31
# 2007-11-06 | 23.5      23.74     21.24    21.39
# ⋮
# 2016-05-11 | 13.92     14.69     13.29    14.69
# 2016-05-12 | 14.55     15.42     13.95    14.41
# 2016-05-13 | 15.15     15.47     13.97    15.04
# 2016-05-16 | 15.72     15.98     14.28    14.68

# %%
vxn=quandl("CBOE/VXN", startdate)
# Out:
# 2149x4 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              Open     High     Low      Close
# 2007-11-01 | 23.95    26.56    23.87    26.26
# 2007-11-02 | 25.8     27.65    24.66    24.83
# 2007-11-05 | 26.85    27.97    26.0     26.1
# 2007-11-06 | 25.82    26.07    23.85    23.91
# ⋮
# 2016-05-11 | 16.27    17.16    15.91    17.16
# 2016-05-12 | 16.65    18.23    16.54    17.26
# 2016-05-13 | 17.45    17.62    16.33    17.1
# 2016-05-16 | 17.1     17.67    15.91    16.37

# %%
ovx=quandl("CBOE/OVX", startdate) # CBOE/OVX since 2007-05-10
# Out:
# 2150x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              USO_VIX_OVX_
# 2007-11-01 | 39.71
# 2007-11-02 | 39.99
# 2007-11-05 | 40.14
# 2007-11-06 | 41.2
# ⋮
# 2016-05-11 | 42.02
# 2016-05-12 | 41.5
# 2016-05-13 | 41.57
# 2016-05-16 | 42.03

# %%
evz=quandl("CBOE/EVZ", startdate) # CBOE/EVZ since 2007-11-01
# Out:
# 2142x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              EVZ
# 2007-11-01 | 8.09
# 2007-11-02 | 8.12
# 2007-11-05 | 7.98
# 2007-11-06 | 8.18
# ⋮
# 2016-05-11 | 9.01
# 2016-05-12 | 9.07
# 2016-05-13 | 9.51
# 2016-05-16 | 9.14

# %%
gvz=quandl("CBOE/GVZ", startdate) # CBOE/GVZ since 2008-6-3
# Out:
# 2004x1 TimeSeries.TimeArray{Float64,2,DataType} 2008-06-03 to 2016-05-16
#
#              GVZ
# 2008-06-03 | 22.89
# 2008-06-04 | 22.69
# 2008-06-05 | 22.78
# 2008-06-06 | 23.6
# ⋮
# 2016-05-11 | 18.35
# 2016-05-12 | 17.84
# 2016-05-13 | 18.29
# 2016-05-16 | 18.49

# %%
oil=quandl("OPEC/ORB", startdate)
# Out:
# 2201x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-12
#
#              Value
# 2007-11-01 | 87.47
# 2007-11-02 | 87.47
# 2007-11-05 | 88.0
# 2007-11-06 | 89.02
# ⋮
# 2016-05-09 | 40.76
# 2016-05-10 | 40.2
# 2016-05-11 | 41.4
# 2016-05-12 | 43.31

# %%
ushybond=quandl("ML/HYOAS", startdate)
# Out:
# 2227x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-13
#
#              VALUE
# 2007-11-01 | 4.53
# 2007-11-02 | 4.65
# 2007-11-05 | 4.69
# 2007-11-06 | 4.66
# ⋮
# 2016-05-10 | 6.46
# 2016-05-11 | 6.4
# 2016-05-12 | 6.36
# 2016-05-13 | 6.41

# %%
usaabond=quandl("ML/AAOAS", startdate)
# Out:
# 2227x1 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-13
#
#              VALUE
# 2007-11-01 | 1.29
# 2007-11-02 | 1.34
# 2007-11-05 | 1.41
# 2007-11-06 | 1.42
# ⋮
# 2016-05-10 | 0.88
# 2016-05-11 | 0.88
# 2016-05-12 | 0.88
# 2016-05-13 | 0.88

# %%
aaii_weekly=quandl("AAII/AAII_SENTIMENT", startdate)
# Out:
# 446x12 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-12
#
#              Bullish  Neutral  Bearish  Total   Bullish_8_Week_Mov_Avg  Bull_Bear_Spread  Bullish_Average  Bullish_Average_St_Dev  Bullish_Average_St_Dev_1  S_P_500_Weekly_High  S_P_500_Weekly_Low  S_P_500_Weekly_Close
# 2007-11-01 | 0.4471   0.1882   0.3647   1.0     0.4412                  0.0824            0.3854           0.4886                  0.2822                    1551.91              1529.42             1549.38
# 2007-11-08 | 0.3619   0.1238   0.5143   1.0     0.4365                  -0.1524           0.3854           0.4886                  0.2822                    1519.49              1475.08             1475.62
# 2007-11-15 | 0.3301   0.1748   0.4951   1.0     0.4287                  -0.165            0.3854           0.4886                  0.2822                    1491.51              1466.99             1470.58
# 2007-11-22 | 0.2558   0.2171   0.5271   1.0     0.3989                  -0.2713           0.3854           0.4886                  0.2822                    1439.62              1415.73             1416.77
# ⋮
# 2016-04-21 | 0.3341   0.4267   0.2392   1.0     0.3172                  0.0948            0.3854           0.4886                  0.2822                    2111.05              2065.9199           2102.3999
# 2016-04-28 | 0.2737   0.4403   0.286    1.0     0.3114                  -0.0123           0.3854           0.4886                  0.2822                    2111.05              2077.52             2095.1499
# 2016-05-05 | 0.2233   0.4733   0.3034   1.0     0.2926                  -0.0801           0.3854           0.4886                  0.2822                    2099.8899            2045.55             2051.1201
# 2016-05-12 | 0.2041   0.483    0.3129   1.0     0.2806                  -0.1088           0.3854           0.4886                  0.2822                    2084.8701            2039.45             2064.46

# %%
oilarray=padseries(oil, eurusd, ["OPEC/ORB"])
gvzarray=padseries(gvz, eurusd, ["CBOE/GVZ"])
evzarray=padseries(evz, eurusd, ["CBOE/EVZ"])
ovxarray=padseries(ovx, eurusd, ["CBOE/OVX"])
vxnarray=padseries(vxn["Close"], eurusd, ["CBOE/VXN"])
vixarray=padseries(vix["VIX_Close"], eurusd, ["CBOE/VIX"])
ushybondarray=padseries(ushybond, eurusd, ["ML/HYOAS"])
usaabondarray=padseries(usaabond, eurusd, ["ML/AAOAS"])
usyieldspreadarray=padseries(ushybondarray.-usaabondarray, eurusd, ["ML/HYOAS-ML/AAOAS"])
predictcount=252
rangelength=35
ta=ohlcv["Close"];

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
function merge2(ta1, ta2)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, [ta1.colnames; ta2.colnames])
end
# Out:
# WARNING: Method definition overlaps(Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[475]:2 overwritten at In[504]:2.
# WARNING: Method definition merge2(Any, Any) in module Main at In[475]:20 overwritten at In[504]:20.
# merge2 (generic function with 1 method)

# %%
function weekly_to_daily(weekly, daily)
    width=length(weekly.colnames)
    merged=merge2(weekly,daily)
    series=daily[merged.timestamp[1]:merged.timestamp[end]]
    sentiment=zeros(length(series),length(merged.colnames))
    for i in merged.timestamp
        idx1=searchsortedfirst(series.timestamp,i)
        idx2=searchsortedfirst(merged.timestamp,i)
        sentiment[idx1,:]=merged.values[idx2,:]
    end
#     # linear interpolation of 2 adjacent values
#     for i=2:length(merged.timestamp)
#         i1=merged.timestamp[i-1]
#         i2=merged.timestamp[i]
#         idx1=searchsortedfirst(series.timestamp,i1)
#         idx2=searchsortedfirst(series.timestamp,i2)
#         span=idx2-idx1
#         d=1/span
#         ds=collect(linspace(d,1-d,span-1))
#         for i=1:length(ds)
#             alpha=ds[i]
#             sentiment[idx1+i,:]=(1-alpha).*sentiment[idx1,:].+alpha.*sentiment[idx2,:]
#         end
#     end
#     last=searchsortedfirst(series.timestamp,merged.timestamp[end])
    last=1
    for i=last+1:size(sentiment,1)
        if sentiment[i,1]==0
            sentiment[i,:]=sentiment[i-1,:]
        end
    end
    TimeArray(series.timestamp,sentiment[:,1:width],merged.colnames[1:width])
end
function aaii_to_daily(weekly, daily)
    merged=weekly_to_daily(weekly, daily)
    idx=searchsortedfirst(daily.timestamp, merged.timestamp[end])
    times=daily.timestamp[idx+1:end]
    n=length(times)
    values=[]
    if n>0
        values=merged.values[end,:]
        for i=2:n
            values=[values merged.values[end,:]]
        end
        values=transpose(values)
    end
    TimeArray([merged.timestamp;times],[merged.values[:,[1:3;5:6]];values[:,[1:3;5:6]]],["AAII/Bullish","AAII/Neutral","AAII/Bearish","AAII/Bullish_8_Week_Mov_Avg","AAII/Bull_Bear_Spread"])
end
# Out:
# WARNING: Method definition weekly_to_daily(Any, Any) in module Main at In[476]:2 overwritten at In[505]:2.
# WARNING: Method definition aaii_to_daily(Any, Any) in module Main at In[476]:35 overwritten at In[505]:35.
# aaii_to_daily (generic function with 1 method)

# %%
function aroon(ta, n=25)
    up=moving(ta,x->findlast(x,maximum(x))/length(x),n)
    down=moving(ta,x->findlast(x,minimum(x))/length(x),n)
    d=up.-down
    r=merge2(up,down)
    r=merge2(r,d)
    TimeArray(r.timestamp,r.values,["aroon$n.up","aroon$n.down","aroon$n.up-down"])
end
# Out:
# WARNING: Method definition aroon(Any) in module Main at In[477]:2 overwritten at In[506]:2.
# WARNING: Method definition aroon(Any, Any) in module Main at In[477]:2 overwritten at In[506]:2.
# aroon (generic function with 2 methods)

# %%
function volumeoscillator(ohlcv, n=28, c="Volume")
    volume=ohlcv[c]
    vshort=ema(volume, int(n/2))
    vlong=ema(volume, n)
    volumeoscillator=(vshort.-vlong)./vlong
    TimeArray(volumeoscillator.timestamp,volumeoscillator.values,["VolumeOscillator$n"])
end
# Out:
# WARNING: Method definition volumeoscillator(Any) in module Main at In[478]:2 overwritten at In[507]:2.
# WARNING: Method definition volumeoscillator(Any, Any) in module Main at In[478]:2 overwritten at In[507]:2.
# WARNING: Method definition volumeoscillator(Any, Any, Any) in module Main at In[478]:2 overwritten at In[507]:2.
# volumeoscillator (generic function with 3 methods)

# %%
function chaikinmoneyflow(ohlcv, n=21, h="High", l="Low", c="Close", v="Volume")
    high=ohlcv[h]
    low=ohlcv[l]
    clo=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = (2.*clo.-low.-high)./(high.-low).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf$n"], ohlcv.meta)
end
# Out:
# WARNING: Method definition chaikinmoneyflow(Any) in module Main at In[479]:2 overwritten at In[508]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any) in module Main at In[479]:2 overwritten at In[508]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any) in module Main at In[479]:2 overwritten at In[508]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any) in module Main at In[479]:2 overwritten at In[508]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any) in module Main at In[479]:2 overwritten at In[508]:2.
# WARNING: Method definition chaikinmoneyflow(Any, Any, Any, Any, Any, Any) in module Main at In[479]:2 overwritten at In[508]:2.
# chaikinmoneyflow (generic function with 6 methods)

# %%
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=merge2(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev$n,$width", "bbstd$n,$width"])
end
function bollingerbands_all(ta, n=20, width=2)
#     b0=bollingerbands_deviation(ta, int(n/2), width)
    b1=bollingerbands_deviation(ta, n, width)
    b2=bollingerbands_deviation(ta, n*2, width)
#     r=merge2(b0,b1)
    merge2(b1,b2)
end
# Out:
# WARNING: Method definition bollingerbands2(TimeSeries.TimeArray{#T<:Any, #N<:Any, M<:Any}, Int64, Real) in module Main at In[480]:2 overwritten at In[509]:2.
# WARNING: Method definition bollingerbands_deviation(Any) in module Main at In[480]:9 overwritten at In[509]:9.
# WARNING: Method definition bollingerbands_deviation(Any, Any) in module Main at In[480]:9 overwritten at In[509]:9.
# WARNING: Method definition bollingerbands_deviation(Any, Any, Any) in module Main at In[480]:9 overwritten at In[509]:9.
# WARNING: Method definition bollingerbands_all(Any) in module Main at In[480]:17 overwritten at In[509]:17.
# WARNING: Method definition bollingerbands_all(Any, Any) in module Main at In[480]:17 overwritten at In[509]:17.
# WARNING: Method definition bollingerbands_all(Any, Any, Any) in module Main at In[480]:17 overwritten at In[509]:17.
# bollingerbands_all (generic function with 3 methods)

# %%
function vwap_divergence(ohlcv, n=28)
    v1=vwap(ohlcv, int(n/2))
    v2=vwap(ohlcv, n)
    v3=vwap(ohlcv, n*2)
    v4=vwap(ohlcv, n*4)
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
    cname=["vwap$(int(n/2))","vwap$n","vwap$(n*2)","vwap$(n*4)","vwap$(int(n/2))-$n","vwap$n-$(n*2)","vwap$(n*2)-$(n*4)"]#,"vwap$(n*8)","vwap$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition vwap_divergence(Any) in module Main at In[481]:2 overwritten at In[510]:2.
# WARNING: Method definition vwap_divergence(Any, Any) in module Main at In[481]:2 overwritten at In[510]:2.
# vwap_divergence (generic function with 2 methods)

# %%
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close")
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{Real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{Real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr$n"], ohlc.meta)
end
function atr_divergence(ohlcv, n=28)
    v1=averagetruerange(ohlcv,int(n/2));
    v2=averagetruerange(ohlcv,n);
    v3=averagetruerange(ohlcv,n*2);
    v4=averagetruerange(ohlcv,n*4);
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
    cname=["atr$(int(n/2))","atr$n","atr$(n*2)","atr$(n*4)","atr$(int(n/2))-$n","atr$n-$(n*2)","atr$(n*2)-$(n*4)"]#,"atr$(n*8)","atr$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
# Out:
# WARNING: Method definition averagetruerange(Any) in module Main at In[482]:2 overwritten at In[511]:2.
# WARNING: Method definition averagetruerange(Any, Any) in module Main at In[482]:2 overwritten at In[511]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any) in module Main at In[482]:2 overwritten at In[511]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any) in module Main at In[482]:2 overwritten at In[511]:2.
# WARNING: Method definition averagetruerange(Any, Any, Any, Any, Any) in module Main at In[482]:2 overwritten at In[511]:2.
# WARNING: Method definition atr_divergence(Any) in module Main at In[482]:12 overwritten at In[511]:12.
# WARNING: Method definition atr_divergence(Any, Any) in module Main at In[482]:12 overwritten at In[511]:12.
# atr_divergence (generic function with 2 methods)

# %%
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pv=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nv=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pv,sum,n)
    nsum=moving(nv,sum,n)
    re=psum./(psum.+nsum)
    TimeArray(re.timestamp, re.values, ["mfi$n"], ohlcv.meta)
end
function rsi_mfi_divergence(rsi, mfi, n=14)
    signal=ema(mfi.-rsi,5)
    TimeArray(signal.timestamp,signal.values,["rsi_mfi_divergence"])
end
function rsi_mfi_all(ohlcv, n=28, c="Close")
    ta=ohlcv[c]
    r1=rsi(ta,n)./100
    m1=moneyflowindex(ohlcv,n)
    merge2(r1,m1)
end
# Out:
# WARNING: Method definition moneyflowindex(Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition moneyflowindex(Any, Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition moneyflowindex(Any, Any, Any, Any, Any, Any) in module Main at In[483]:2 overwritten at In[512]:2.
# WARNING: Method definition rsi_mfi_divergence(Any, Any) in module Main at In[483]:18 overwritten at In[512]:18.
# WARNING: Method definition rsi_mfi_divergence(Any, Any, Any) in module Main at In[483]:18 overwritten at In[512]:18.
# WARNING: Method definition rsi_mfi_all(Any) in module Main at In[483]:22 overwritten at In[512]:22.
# WARNING: Method definition rsi_mfi_all(Any, Any) in module Main at In[483]:22 overwritten at In[512]:22.
# WARNING: Method definition rsi_mfi_all(Any, Any, Any) in module Main at In[483]:22 overwritten at In[512]:22.
# rsi_mfi_all (generic function with 3 methods)

# %%
function ChandeMomentumOscillator(ohlcv, n=9, h="High", l="Low", c="Close")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pv=TimeArray(diff.timestamp,positive,["Positive"])
    nv=TimeArray(diff.timestamp,negative,["Negative"])
    psum=moving(pv,sum,n)
    nsum=moving(nv,sum,n)
    re=(psum.-nsum)./(psum.+nsum)
    TimeArray(re.timestamp, re.values, ["cmo$n"], ohlcv.meta)
end
function MoneyFlowOscillator(ohlcv, n=9, h="High", l="Low", c="Close", v="Volume")
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{Real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{Real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pv=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nv=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pv,sum,n)
    nsum=moving(nv,sum,n)
    re=(psum.-nsum)./(psum.+nsum)
    TimeArray(re.timestamp, re.values, ["mf$n"], ohlcv.meta)
end
function MoneyFlowDivergence(ohlcv, n=9, h="High", l="Low", c="Close", v="Volume")
    cmo=ChandeMomentumOscillator(ohlcv, n)
    mfo=MoneyFlowOscillator(ohlcv, n)
    diff=mfo.-cmo
    TimeArray(diff.timestamp,diff.values,["mfd$n"])
end
function mfo_all(ohlcv, n=9, signal=7, h="High", l="Low", c="Close", v="Volume")
    mf1=MoneyFlowDivergence(ohlcv, int(n/2))
    mf2=MoneyFlowDivergence(ohlcv, n)
    d1=mf1.-mf2
    re=ema(d1, signal)
    TimeArray(re.timestamp,re.values,["mfo$n"])
end
# Out:
# WARNING: Method definition ChandeMomentumOscillator(Any) in module Main at In[484]:2 overwritten at In[513]:2.
# WARNING: Method definition ChandeMomentumOscillator(Any, Any) in module Main at In[484]:2 overwritten at In[513]:2.
# WARNING: Method definition ChandeMomentumOscillator(Any, Any, Any) in module Main at In[484]:2 overwritten at In[513]:2.
# WARNING: Method definition ChandeMomentumOscillator(Any, Any, Any, Any) in module Main at In[484]:2 overwritten at In[513]:2.
# WARNING: Method definition ChandeMomentumOscillator(Any, Any, Any, Any, Any) in module Main at In[484]:2 overwritten at In[513]:2.
# WARNING: Method definition MoneyFlowOscillator(Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowOscillator(Any, Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowOscillator(Any, Any, Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowOscillator(Any, Any, Any, Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowOscillator(Any, Any, Any, Any, Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowOscillator(Any, Any, Any, Any, Any, Any) in module Main at In[484]:17 overwritten at In[513]:17.
# WARNING: Method definition MoneyFlowDivergence(Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition MoneyFlowDivergence(Any, Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition MoneyFlowDivergence(Any, Any, Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition MoneyFlowDivergence(Any, Any, Any, Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition MoneyFlowDivergence(Any, Any, Any, Any, Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition MoneyFlowDivergence(Any, Any, Any, Any, Any, Any) in module Main at In[484]:33 overwritten at In[513]:33.
# WARNING: Method definition mfo_all(Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any, Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any, Any, Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any, Any, Any, Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# WARNING: Method definition mfo_all(Any, Any, Any, Any, Any, Any, Any) in module Main at In[484]:39 overwritten at In[513]:39.
# mfo_all (generic function with 7 methods)

# %%
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    r = merge(mcd, sig, col_names=["macd($fast,$slow,$signal)", "signal"])
#     merge(r, mcd .- sig, col_names=[r.colnames; ["histogram"]])
end
# Out:
# WARNING: Method definition macd2(Any) in module Main at In[485]:2 overwritten at In[514]:2.
# WARNING: Method definition macd2(Any, Any) in module Main at In[485]:2 overwritten at In[514]:2.
# WARNING: Method definition macd2(Any, Any, Any) in module Main at In[485]:2 overwritten at In[514]:2.
# WARNING: Method definition macd2(Any, Any, Any, Any) in module Main at In[485]:2 overwritten at In[514]:2.
# macd2 (generic function with 4 methods)

# %%
function priceindex(ta, n=28)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=merge2(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["priceindex$n"]])
end
# Out:
# WARNING: Method definition priceindex(Any) in module Main at In[486]:2 overwritten at In[515]:2.
# WARNING: Method definition priceindex(Any, Any) in module Main at In[486]:2 overwritten at In[515]:2.
# priceindex (generic function with 2 methods)

# %%
aaiiarray=aaii_to_daily(aaii_weekly, eurusd)
# Out:
# 2184x5 TimeSeries.TimeArray{Float64,2,DataType} 2007-11-01 to 2016-05-16
#
#              AAII/Bullish  AAII/Neutral  AAII/Bearish  AAII/Bullish_8_Week_Mov_Avg  AAII/Bull_Bear_Spread
# 2007-11-01 | 0.4471        0.1882        0.3647        0.4412                       0.0824
# 2007-11-02 | 0.4471        0.1882        0.3647        0.4412                       0.0824
# 2007-11-05 | 0.4471        0.1882        0.3647        0.4412                       0.0824
# 2007-11-06 | 0.4471        0.1882        0.3647        0.4412                       0.0824
# ⋮
# 2016-05-11 | 0.2233        0.4733        0.3034        0.2926                       -0.0801
# 2016-05-12 | 0.2041        0.483         0.3129        0.2806                       -0.1088
# 2016-05-13 | 0.2041        0.483         0.3129        0.2806                       -0.1088
# 2016-05-16 | 0.2041        0.483         0.3129        0.2806                       -0.1088

# %%
rsimfiarray=rsi_mfi_all(ohlcv,rangelength);
macdarray=macd2(ta,int(rangelength/2),rangelength);
vwaparray=vwap_divergence(ohlcv,rangelength);
atrarray=atr_divergence(ohlcv,rangelength);
aroonarray=aroon(ta,rangelength);
volumeoscillatorarray=volumeoscillator(ohlcv,rangelength);
cmfarray=chaikinmoneyflow(ohlcv,rangelength);
bbarray=bollingerbands_all(ta,rangelength,2);
# mfoarray=mfo_all(ohlcv, int(rangelength/2));
priceindexarray=priceindex(ta,rangelength);
# Out:
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in vwap_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[510]:2
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 3
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in vwap_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[510]:15
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 3
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  [inlined code] from ./strings/io.jl:73
#  in vwap_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[510]:15
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 3
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in atr_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[511]:12
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 4
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in atr_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[511]:25
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 4
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  [inlined code] from ./strings/io.jl:73
#  in atr_divergence(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[511]:25
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 4
# WARNING: int(x::AbstractFloat) is deprecated, use round(Int,x) instead.

# %%
featurearray=merge2(bbarray,cmfarray);
# featurearray=merge2(featurearray,mfoarray);
featurearray=merge2(featurearray,macdarray);
featurearray=merge2(featurearray,volumeoscillatorarray);
featurearray=merge2(featurearray,rsimfiarray);
featurearray=merge2(featurearray,atrarray);
featurearray=merge2(featurearray,vwaparray);
featurearray=merge2(featurearray,aroonarray);
featurearray=merge2(featurearray,ustreasuryarray);
featurearray=merge2(featurearray,ushybondarray);
featurearray=merge2(featurearray,usaabondarray);
featurearray=merge2(featurearray,usyieldspreadarray);
featurearray=merge2(featurearray,vixarray);
featurearray=merge2(featurearray,vxnarray);
featurearray=merge2(featurearray,goldarray);
featurearray=merge2(featurearray,gvzarray);
featurearray=merge2(featurearray,oilarray);
featurearray=merge2(featurearray,ovxarray);
featurearray=merge2(featurearray,eurusdarray);
featurearray=merge2(featurearray,evzarray);
featurearray=merge2(featurearray,aaiiarray);
# Out:
#  [inlined code] from ./error.jl:26
#  in depwarn(::ASCIIString, ::Symbol) at ./deprecated.jl:64
#  in int(::Float64) at ./deprecated.jl:50
#  in volumeoscillator(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64, ::ASCIIString) at ./In[507]:3
#  in volumeoscillator(::TimeSeries.TimeArray{Real,2,DataType}, ::Int64) at ./In[507]:2
#  [inlined code] from ./essentials.jl:82
#  in include_string(::ASCIIString, ::ASCIIString) at ./loading.jl:371
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:177
#  [inlined code] from ./dict.jl:779
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:141
#  in (::IJulia.##24#30)() at ./task.jl:308
# while loading In[517], in expression starting on line 6

# %%
withlabel=merge2(featurearray,priceindexarray)
# Out:
# 1934x48 TimeSeries.TimeArray{Real,2,DataType} 2008-06-03 to 2016-03-29
#
#              bbdev35,2  bbstd35,2  bbdev70,2  bbstd70,2  cmf35   macd(18,35,9)  signal  VolumeOscillator35  rsi     mfi35   atr18   atr35   atr70   atr140  atr18-35  atr35-70  atr70-140  vwap18    vwap35    vwap70    vwap140   vwap18-35  vwap35-70  vwap70-140  aroon35.up  aroon35.down  aroon35.up-down  USTREASURY/REALLONGTERM  ML/HYOAS  ML/AAOAS  ML/HYOAS-ML/AAOAS  CBOE/VIX  CBOE/VXN  WGC/GOLD_DAILY_USD  CBOE/GVZ  OPEC/ORB  CBOE/OVX  ECB/EURUSD  CBOE/EVZ  AAII/Bullish  AAII/Neutral  AAII/Bearish  AAII/Bullish_8_Week_Mov_Avg  AAII/Bull_Bear_Spread  Close     min       max       priceindex35
# 2008-06-03 | 0.3459     1.4082     0.6161     2.569      0.1688  0.7989         0.8637  0.0099              0.564   0.6702  0.8993  0.9583  1.0337  1.0819  -0.0589   -0.0754   -0.0483    49.1149   48.1934   45.649    46.7377   0.9215     2.5444     -1.0887     0.9429      0.0286        0.9143           2.12                     6.78      2.09      4.69               20.24     23.89     1.1126              22.89     121.68    41.75     1.5593      9.98      0.3136        0.2288        0.4576        0.4396                       -0.144                 49.13     44.23     50.55     0.7753
# 2008-06-04 | 0.5761     1.2531     0.715      2.5957     0.1727  0.7955         0.8501  0.0245              0.5968  0.688   0.9138  0.964   1.0355  1.0825  -0.0502   -0.0714   -0.047     49.1994   48.3676   45.7442   46.7361   0.8318     2.6234     -0.9919     0.9143      0.0571        0.8571           2.21                     6.79      2.11      4.68               20.8      24.01     1.118               22.69     118.55    40.77     1.5466      9.92      0.3136        0.2288        0.4576        0.4396                       -0.144                 49.76     44.23     50.55     0.875
# 2008-06-05 | 0.8682     1.2012     0.8355     2.6387     0.1756  0.8272         0.8455  0.0191              0.6335  0.6764  0.9136  0.9625  1.0337  1.0813  -0.0489   -0.0712   -0.0476    49.3085   48.5198   45.832    46.7113   0.7888     2.6878     -0.8793     1.0         0.0286        0.9714           2.27                     6.63      2.09      4.54               18.63     22.85     1.112               22.78     118.75    41.37     1.5402      10.0      0.4348        0.1848        0.3804        0.4368                       0.0544                 50.55     44.23     50.55     1.0
# 2008-06-06 | 0.2138     1.0719     0.5322     2.6512     0.1269  0.7736         0.8311  0.0366              0.5345  0.6136  0.9478  0.9787  1.0408  1.0845  -0.0309   -0.0621   -0.0437    49.2956   48.631    45.9133   46.6906   0.6646     2.7177     -0.7773     0.9714      0.0857        0.8857           2.14                     6.68      2.08      4.6                23.56     26.04     1.1269              23.6      126.09    52.03     1.5597      10.08     0.4348        0.1848        0.3804        0.4368                       0.0544                 49.03     44.23     49.03     1.0
# ⋮
# 2016-03-22 | 0.7142     3.4821     0.3036     4.6703     0.2088  0.8933         0.5124  -0.1372             0.613   0.442   1.6235  1.8149  1.84    1.7119  -0.1914   -0.0251   0.1281     105.7787  101.8958  104.2151  106.0202  3.8829     -2.3193    -1.8051     1.0         0.1714        0.8286           0.78                     6.69      0.96      5.73               14.17     16.98     1.5849              17.62     36.67     44.12     1.1212      8.91      0.2996        0.4318        0.2686        0.2933                       0.031                  108.12    105.02    111.23    0.4992
# 2016-03-23 | 0.5559     3.5429     0.2223     4.5735     0.2279  0.9105         0.5921  -0.1463             0.5759  0.4608  1.5961  1.7953  1.8299  1.7078  -0.1993   -0.0345   0.1221     105.9765  101.9696  104.1439  106.0927  4.0069     -2.1743    -1.9489     0.9714      0.1429        0.8286           0.74                     6.79      0.95      5.84               14.94     17.75     1.5408              18.0      36.19     44.58     1.1171      9.15      0.2996        0.4318        0.2686        0.2933                       0.031                  107.23    105.02    111.23    0.3559
# 2016-03-24 | 0.5302     3.5918     0.2333     4.5308     0.239   0.9211         0.6579  -0.1571             0.5768  0.4849  1.5496  1.7658  1.8146  1.701   -0.2161   -0.0488   0.1136     106.2112  102.0606  104.0382  106.115   4.1506     -1.9776    -2.0767     0.9429      0.1143        0.8286           0.78                     6.93      0.96      5.97               14.74     17.31     1.5451              18.09     34.96     44.96     1.1154      8.98      0.3378        0.4251        0.2371        0.2983                       0.1007                 107.26    105.02    111.23    0.3607
# 2016-03-29 | 0.6821     3.6044     0.4308     4.408      0.308   0.9941         0.7666  -0.1618             0.622   0.5726  1.5374  1.7466  1.8034  1.697   -0.2092   -0.0568   0.1064     106.4501  102.5215  103.8255  106.1931  3.9287     -1.304     -2.3676     1.0         0.0571        0.9429           0.67                     7.14      0.95      6.19               13.82     16.9      1.5514              19.52     34.5      46.63     1.1194      9.09      0.3378        0.4251        0.2371        0.2983                       0.1007                 108.83    105.02    111.23    0.6135

# %%
withoutlabel=merge2(featurearray,ta)
# Out:
# 1968x45 TimeSeries.TimeArray{Real,2,DataType} 2008-06-03 to 2016-05-16
#
#              bbdev35,2  bbstd35,2  bbdev70,2  bbstd70,2  cmf35   macd(18,35,9)  signal  VolumeOscillator35  rsi     mfi35   atr18   atr35   atr70   atr140  atr18-35  atr35-70  atr70-140  vwap18    vwap35    vwap70    vwap140   vwap18-35  vwap35-70  vwap70-140  aroon35.up  aroon35.down  aroon35.up-down  USTREASURY/REALLONGTERM  ML/HYOAS  ML/AAOAS  ML/HYOAS-ML/AAOAS  CBOE/VIX  CBOE/VXN  WGC/GOLD_DAILY_USD  CBOE/GVZ  OPEC/ORB  CBOE/OVX  ECB/EURUSD  CBOE/EVZ  AAII/Bullish  AAII/Neutral  AAII/Bearish  AAII/Bullish_8_Week_Mov_Avg  AAII/Bull_Bear_Spread  Close
# 2008-06-03 | 0.3459     1.4082     0.6161     2.569      0.1688  0.7989         0.8637  0.0099              0.564   0.6702  0.8993  0.9583  1.0337  1.0819  -0.0589   -0.0754   -0.0483    49.1149   48.1934   45.649    46.7377   0.9215     2.5444     -1.0887     0.9429      0.0286        0.9143           2.12                     6.78      2.09      4.69               20.24     23.89     1.1126              22.89     121.68    41.75     1.5593      9.98      0.3136        0.2288        0.4576        0.4396                       -0.144                 49.13
# 2008-06-04 | 0.5761     1.2531     0.715      2.5957     0.1727  0.7955         0.8501  0.0245              0.5968  0.688   0.9138  0.964   1.0355  1.0825  -0.0502   -0.0714   -0.047     49.1994   48.3676   45.7442   46.7361   0.8318     2.6234     -0.9919     0.9143      0.0571        0.8571           2.21                     6.79      2.11      4.68               20.8      24.01     1.118               22.69     118.55    40.77     1.5466      9.92      0.3136        0.2288        0.4576        0.4396                       -0.144                 49.76
# 2008-06-05 | 0.8682     1.2012     0.8355     2.6387     0.1756  0.8272         0.8455  0.0191              0.6335  0.6764  0.9136  0.9625  1.0337  1.0813  -0.0489   -0.0712   -0.0476    49.3085   48.5198   45.832    46.7113   0.7888     2.6878     -0.8793     1.0         0.0286        0.9714           2.27                     6.63      2.09      4.54               18.63     22.85     1.112               22.78     118.75    41.37     1.5402      10.0      0.4348        0.1848        0.3804        0.4368                       0.0544                 50.55
# 2008-06-06 | 0.2138     1.0719     0.5322     2.6512     0.1269  0.7736         0.8311  0.0366              0.5345  0.6136  0.9478  0.9787  1.0408  1.0845  -0.0309   -0.0621   -0.0437    49.2956   48.631    45.9133   46.6906   0.6646     2.7177     -0.7773     0.9714      0.0857        0.8857           2.14                     6.68      2.08      4.6                23.56     26.04     1.1269              23.6      126.09    52.03     1.5597      10.08     0.4348        0.1848        0.3804        0.4368                       0.0544                 49.03
# ⋮
# 2016-05-11 | -0.5407    1.8927     0.0759     3.8435     0.0654  -0.2747        0.0147  -0.0371             0.4597  0.3818  1.3441  1.4942  1.6324  1.6242  -0.1501   -0.1382   0.0083     107.366   108.2212  104.3532  106.8371  -0.8552    3.868      -2.4839     0.5143      0.8857        -0.3714          0.62                     6.4       0.88      5.52               14.69     17.16     1.6158              18.35     41.4      42.02     1.1409      9.01      0.2233        0.4733        0.3034        0.2926                       -0.0801                106.36
# 2016-05-12 | -0.6423    1.9293     0.0079     3.8186     0.075   -0.3188        -0.052  -0.0298             0.4429  0.3726  1.3583  1.4972  1.632   1.624   -0.1389   -0.1347   0.008      107.1545  108.168   104.4173  106.8274  -1.0135    3.7507     -2.4101     0.4857      0.8571        -0.3714          0.63                     6.36      0.88      5.48               14.41     17.26     1.6189              17.84     43.31     41.5      1.1389      9.07      0.2041        0.483         0.3129        0.2806                       -0.1088                105.89
# 2016-05-13 | -0.7117    1.9798     -0.0508    3.7857     0.04    -0.3736        -0.1163 -0.0386             0.4292  0.3749  1.3473  1.4876  1.6252  1.6207  -0.1403   -0.1376   0.0045     106.7881  108.1242  104.5047  106.7967  -1.3362    3.6195     -2.292      0.4571      0.8286        -0.3714          0.6                      6.41      0.88      5.53               15.04     17.1      1.6019              18.29     43.31     41.57     1.1348      9.51      0.2041        0.483         0.3129        0.2806                       -0.1088                105.5
# 2016-05-16 | -0.3752    1.9854     0.1148     3.7527     0.0572  -0.3521        -0.1635 -0.0516             0.4864  0.3881  1.3674  1.4939  1.6264  1.6213  -0.1265   -0.1325   0.0051     106.6467  108.1133  104.589   106.7317  -1.4666    3.5243     -2.1427     0.4286      0.8           -0.3714          0.62                     6.41      0.88      5.53               14.68     16.37     1.6271              18.49     43.31     42.03     1.1324      9.14      0.2041        0.483         0.3129        0.2806                       -0.1088                106.82

# %%
dataoffset=length(withoutlabel)-length(withlabel)
lastdate=withlabel.timestamp[end]
lastdateidx=searchsortedfirst(withoutlabel.timestamp, lastdate)
splitidx=lastdateidx-predictcount+dataoffset
newfeatures=TimeArray(withoutlabel.timestamp[splitidx+1:end],withoutlabel.values[splitidx+1:end,:],withoutlabel.colnames);

# %%
training=TimeArray(withlabel.timestamp[1:splitidx],withlabel.values[1:splitidx,:],withlabel.colnames);

# %%
test=TimeArray(withlabel.timestamp[splitidx+1:end],withlabel.values[splitidx+1:end,:],withlabel.colnames);

# %%
rsiidx=findfirst(withlabel.colnames,"rsi")
mfiidx=findfirst(withlabel.colnames,"mfi$rangelength")
bbsidx=findfirst(withlabel.colnames,"AAII/Bull_Bear_Spread")
pricerangeidx=findfirst(withlabel.colnames,"priceindex$rangelength")
closeidx=findfirst(withlabel.colnames,"Close")
# Out:
# 45

# %%
randomfeaturenum=floor(Int,sqrt(closeidx))
# Out:
# 6

# %%
plot(withlabel.timestamp,withlabel.values[:,1:closeidx])
legend(withlabel.colnames[1:closeidx],bbox_to_anchor=(1.62, 1.02))
title("Features for training")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f507fcec910>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
using DecisionTree
ntrees=100
features=training.values[:,1:closeidx]
labels=convert(Array{Float64,1},training.values[:,pricerangeidx])
# train regression forest, using 2 random features, 10 trees,
# averaging of 5 samples per leaf (optional), 0.7 of samples per tree (optional)
model = build_forest(labels, features, randomfeaturenum, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 416.99
# Avg Depth:  26.75

# %%
newlabels=apply_forest(model, newfeatures.values);
initvalue=withlabel.values[1,closeidx];

# %%
plot(withoutlabel.timestamp,withoutlabel.values[:,closeidx]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,closeidx+1:closeidx+2]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,rsiidx],c="c")
plot(withlabel.timestamp,withlabel.values[:,mfiidx],c="DarkOrange")
plot(training.timestamp,training.values[:,pricerangeidx],c="Grey")
plot(newfeatures.timestamp,newlabels,c="k")
title("$symbol history & forecast")
grid("on")
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
legend([withlabel.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx,mfiidx,pricerangeidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f508435cfd0>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue)
plot(test.timestamp,test.values[:,closeidx+1:closeidx+2]./initvalue)
plot(newfeatures.timestamp,newfeatures.values[:,rsiidx],c="c")
plot(newfeatures.timestamp,newfeatures.values[:,mfiidx],c="DarkOrange")
plot(newfeatures.timestamp,newfeatures.values[:,bbsidx],c="m")
plot(test.timestamp,test.values[:,pricerangeidx],c="Grey")
plot(newfeatures.timestamp,newlabels,c="k")
legend([test.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx,mfiidx,bbsidx,pricerangeidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
title("$symbol forecast: random forest with $ntrees trees, period=$rangelength")
grid("on")
# color names http://astropython.blogspot.ie/2012/02/additional-color-names-for-matplotlib.html
# http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.axhline
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f507fc56310>)
# MethodError: no method matching writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
# Closest candidates are:
#   writemime(::IO, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject)
#   writemime(::IO, !Matched::AbstractString, ::Any)
#   writemime(::IO, !Matched::MIME{symbol("text/csv")}, ::Any)
#   ...
#
#  in writemime(::Base.AbstractIOBuffer{Array{UInt8,1}}, ::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:502
#  in #sprint#97(::Void, ::Any, ::Int64, ::Any, ::MIME{symbol("image/svg+xml")}, ::Vararg{Any}) at ./strings/io.jl:38
#  in stringmime(::MIME{symbol("image/svg+xml")}, ::PyCall.PyObject) at ./multimedia.jl:73
#  in display_dict(::Any) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:29

# %%
features=withlabel.values[:,1:closeidx]
labels=convert(Array{Float64,1},withlabel.values[:,pricerangeidx])
# run n-fold cross validation on regression forest
# using 2 random features, 10 trees, 3 folds, averaging of 5 samples/leaf (optional),
# and 0.7 porition of samples per tree (optional)
# returns array of coefficients of determination (R^2)
r2 = nfoldCV_forest(labels, features, 2, ntrees, 3, 5, 0.7)
# Out:
# Fold 1
# Mean Squared Error:     0.020183650113149564
# Correlation Coeff:      0.9385270613748449
# Coeff of Determination: 0.8190795297777913
#
# Fold 2
# Mean Squared Error:     0.023147271368524087
# Correlation Coeff:      0.9261766169711175
# Coeff of Determination: 0.7923778820577634
#
# Fold 3
# 3-element Array{Float64,1}:
#  0.81908
#  0.792378
#  0.814375
# Mean Squared Error:     0.021051383456216988
# Correlation Coeff:      0.9374525480459043
# Coeff of Determination: 0.8143746259906945
#
# Mean Coeff of Determination: 0.8086106792754165
