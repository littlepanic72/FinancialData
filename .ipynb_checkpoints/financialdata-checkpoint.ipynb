# %%
using PyPlot
using DataFrames
using Requests
using TimeSeries
using MarketTechnicals
using DecisionTree
# Out:
# INFO: Recompiling stale cache file /home/juser/.julia/lib/v0.5/PyCall.ji for module PyCall.
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in process_options(::Base.JLOptions) at ./client.jl:240
#  in _start() at ./client.jl:319
# while loading /home/juser/.julia/v0.5/PyCall/src/../deps/deps.jl, in expression starting on line 3
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in process_options(::Base.JLOptions) at ./client.jl:240
#  in _start() at ./client.jl:319
# while loading /home/juser/.julia/v0.5/PyCall/src/../deps/deps.jl, in expression starting on line 5
# WARNING: bytestring(p::Union{Ptr{Int8},Ptr{UInt8}}) is deprecated, use String(p) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Ptr{UInt8}) at ./deprecated.jl:50
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:53
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in stale_cachefile(::String, ::String) at ./loading.jl:562
#  in recompile_stale(::Symbol, ::String) at ./loading.jl:579
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:173
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[1], in expression starting on line 1
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in pyeval_(::String, ::PyCall.PyDict{AbstractString,PyCall.PyObject}, ::Int64) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:669
#  in #pyeval#48(::Array{Any,1}, ::Function, ::String, ::Type{PyCall.PyAny}, ::PyCall.PyDict{AbstractString,PyCall.PyObject}, ::Int64) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:701
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:91
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in stale_cachefile(::String, ::String) at ./loading.jl:562
#  in recompile_stale(::Symbol, ::String) at ./loading.jl:579
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:173
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[1], in expression starting on line 1
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:97
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in stale_cachefile(::String, ::String) at ./loading.jl:562
#  in recompile_stale(::Symbol, ::String) at ./loading.jl:579
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:173
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[1], in expression starting on line 1
# INFO: Recompiling stale cache file /home/juser/.julia/lib/v0.5/PyPlot.ji for module PyPlot.
# WARNING: bytestring(p::Union{Ptr{Int8},Ptr{UInt8}}) is deprecated, use String(p) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Ptr{UInt8}) at ./deprecated.jl:50
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:53
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_from_node1(::String) at ./loading.jl:426
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in process_options(::Base.JLOptions) at ./client.jl:240
#  in _start() at ./client.jl:319
# while loading /home/juser/.julia/v0.5/PyPlot/src/PyPlot.jl, in expression starting on line 5
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in pyeval_(::String, ::PyCall.PyDict{AbstractString,PyCall.PyObject}, ::Int64) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:669
#  in #pyeval#48(::Array{Any,1}, ::Function, ::String, ::Type{PyCall.PyAny}, ::PyCall.PyDict{AbstractString,PyCall.PyObject}, ::Int64) at /home/juser/.julia/v0.5/PyCall/src/PyCall.jl:701
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:91
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_from_node1(::String) at ./loading.jl:426
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in process_options(::Base.JLOptions) at ./client.jl:240
#  in _start() at ./client.jl:319
# while loading /home/juser/.julia/v0.5/PyPlot/src/PyPlot.jl, in expression starting on line 5
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in __init__() at /home/juser/.julia/v0.5/PyCall/src/pyinit.jl:97
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_from_node1(::String) at ./loading.jl:426
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in process_options(::Base.JLOptions) at ./client.jl:240
#  in _start() at ./client.jl:319
# while loading /home/juser/.julia/v0.5/PyPlot/src/PyPlot.jl, in expression starting on line 5
# WARNING: bytestring(p::Union{Ptr{Int8},Ptr{UInt8}},len::Integer) is deprecated, use String(p,len) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Ptr{UInt8}, ::Int64) at ./deprecated.jl:50
#  in convert(::Type{AbstractString}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/conversions.jl:83
#  in convert(::Type{PyCall.PyAny}, ::PyCall.PyObject) at /home/juser/.julia/v0.5/PyCall/src/conversions.jl:798
#  in __init__() at /home/juser/.julia/v0.5/PyPlot/src/PyPlot.jl:214
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[1], in expression starting on line 1
# WARNING: bytestring(s::AbstractString...) is deprecated, use string(s...) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::String) at ./deprecated.jl:50
#  in crt_parse at /home/juser/.julia/v0.5/MbedTLS/src/x509_crt.jl:40 [inlined]
#  in crt_parse_file at /home/juser/.julia/v0.5/MbedTLS/src/x509_crt.jl:36 [inlined]
#  in ca_chain! at /home/juser/.julia/v0.5/MbedTLS/src/ssl.jl:66 [inlined]
#  in get_default_tls_config(::Bool) at /home/juser/.julia/v0.5/Requests/src/streaming.jl:100
#  in __init_streaming__() at /home/juser/.julia/v0.5/Requests/src/streaming.jl:221
#  in __init__() at /home/juser/.julia/v0.5/Requests/src/Requests.jl:38
#  in _require_from_serialized(::Int64, ::Symbol, ::String, ::Bool) at ./loading.jl:174
#  in _require_from_serialized(::Int64, ::Symbol, ::Bool) at ./loading.jl:202
#  in require(::Symbol) at ./loading.jl:332
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[1], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 7
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 7
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 29
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 30
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 33
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 34
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 181
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 192
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl, in expression starting on line 204
# WARNING: module TimeSeries should explicitly import .+ from Base
# WARNING: module TimeSeries should explicitly import .- from Base
# WARNING: module TimeSeries should explicitly import .* from Base
# WARNING: module TimeSeries should explicitly import ./ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import .^ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import + from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import - from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import * from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import / from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: module TimeSeries should explicitly import ^ from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:60 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 61
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:70 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 71
# WARNING: module TimeSeries should explicitly import .> from Base
# WARNING: module TimeSeries should explicitly import .< from Base
# WARNING: module TimeSeries should explicitly import .== from Base
# WARNING: module TimeSeries should explicitly import .>= from Base
# WARNING: module TimeSeries should explicitly import .<= from Base
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:104 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:104 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:104 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:104 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:104 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 105
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:118 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:118 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:118 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in macro expansion; at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:118 [inlined]
#  in anonymous at ./<missing>:?
#  in include_from_node1(::String) at ./loading.jl:426 (repeats 2 times)
#  in eval(::Module, ::Any) at ./boot.jl:225
#  in require(::Symbol) at ./loading.jl:357
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading /home/juser/.julia/v0.5/TimeSeries/src/apply.jl, in expression starting on line 119
# WARNING: Union(args...) is deprecated, use Union{args...} instead.

# %%
function csvtotimearray(url, count=Void)
    df = readtable(Requests.get_streaming(url))
    timestamp = Date[Date(i) for i in df[1]] # parse dates
    colnames=String[string(i) for i in DataFrames.names(df)]
    offset=(Void==count||count<1||count>length(DataFrames.names(df))-1)?(length(DataFrames.names(df))-2):(count-1)
    dataarray=convert(Array, df[end-offset:end])
    TimeArray(timestamp,dataarray,colnames[end-offset:end])
end
function yahoo(symbol, startdate)
    str="a=$(Dates.month(startdate)-1)"*Dates.format(startdate, "&b=dd&c=yyyy")
    url="http://real-chart.finance.yahoo.com/table.csv?s="*symbol*"&"*str*"&g=d&ignore=.csv"
    csvtotimearray(url)
end
function quandl(symbol, startdate, count=Void)
    str=Dates.format(startdate, "yyyy-mm-dd")
    url="https://www.quandl.com/api/v3/datasets/$symbol.csv?api_key=VKyXNok9WfyAwAHtZBCR&start_date=$str"
    csvtotimearray(url, count)
end
function renameta(series, columns)
    TimeArray(series.timestamp,series.values,columns)
end
# Out:
# renameta (generic function with 1 method)

# %%
startdate=Date(2007,10,1) # set an early date to make use of all CBOE/GVZ data
# symbol="YCS" # TLT GLD USO SPY YCS EUO UUP
# ohlcv=yahoo(symbol, startdate)
symbol="YAHOO/INDEX_SPY"
ohlcv=quandl(symbol, startdate)
ohlcv.timestamp[[1,end]]
# Out:
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: bytestring(p::Union{Ptr{Int8},Ptr{UInt8}}) is deprecated, use String(p) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Ptr{UInt8}) at ./deprecated.jl:50
#  in on_header_field(::Ptr{HttpParser.Parser}, ::Ptr{Int8}, ::UInt64) at /home/juser/.julia/v0.5/Requests/src/parsing.jl:43
#  in http_parser_execute(::HttpParser.Parser, ::HttpParser.ParserSettings, ::Array{UInt8,1}) at /home/juser/.julia/v0.5/HttpParser/src/HttpParser.jl:92
#  in macro expansion at /home/juser/.julia/v0.5/Requests/src/streaming.jl:70 [inlined]
#  in (::Requests.##6#8{Requests.ResponseStream{MbedTLS.SSLContext},Requests.ResponseParser,Channel{Symbol}})() at ./event.jl:46
# while loading In[3], in expression starting on line 5
# WARNING: bytestring(p::Union{Ptr{Int8},Ptr{UInt8}},len::Integer) is deprecated, use String(p,len) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Ptr{UInt8}, ::Int64) at ./deprecated.jl:50
#  in on_header_value(::Ptr{HttpParser.Parser}, ::Ptr{Int8}, ::UInt64) at /home/juser/.julia/v0.5/Requests/src/parsing.jl:84
#  in http_parser_execute(::HttpParser.Parser, ::HttpParser.ParserSettings, ::Array{UInt8,1}) at /home/juser/.julia/v0.5/HttpParser/src/HttpParser.jl:92
#  in macro expansion at /home/juser/.julia/v0.5/Requests/src/streaming.jl:70 [inlined]
#  in (::Requests.##6#8{Requests.ResponseStream{MbedTLS.SSLContext},Requests.ResponseParser,Channel{Symbol}})() at ./event.jl:46
# while loading In[3], in expression starting on line 5
# WARNING: bytestring(v::Vector{UInt8}) is deprecated, use String(v) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Array{UInt8,1}) at ./deprecated.jl:50
#  in parsenames!(::Array{Symbol,1}, ::Bool, ::Array{UInt8,1}, ::Array{Int64,1}, ::BitArray{1}, ::Int64, ::Bool) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:685
#  in readtable!(::DataFrames.ParsedCSV, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64, ::DataFrames.ParseOptions{String,String}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:772
#  in #readtable#26(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:859
#  in readtable(::Requests.ResponseStream{MbedTLS.SSLContext}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:828
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:2
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[3], in expression starting on line 5
# WARNING: bytestring(v::Vector{UInt8}) is deprecated, use String(v) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Array{UInt8,1}) at ./deprecated.jl:50
#  in bytestotype(::Type{String}, ::Array{UInt8,1}, ::Int64, ::Int64, ::Array{String,1}, ::Bool, ::Array{String,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:502
#  in builddf(::Int64, ::Int64, ::Int64, ::Int64, ::DataFrames.ParsedCSV, ::DataFrames.ParseOptions{String,String}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:634
#  in readtable!(::DataFrames.ParsedCSV, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64, ::DataFrames.ParseOptions{String,String}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:800
#  in #readtable#26(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::Requests.ResponseStream{MbedTLS.SSLContext}, ::Int64) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:859
#  in readtable(::Requests.ResponseStream{MbedTLS.SSLContext}) at /home/juser/.julia/v0.5/DataFrames/src/dataframe/io.jl:828
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:2
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[3], in expression starting on line 5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[3]:5
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: utf8(s::AbstractString) is deprecated, use String(s) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in utf8(::String) at ./deprecated.jl:50
#  in _collect(::Array{String,1}, ::Base.Generator{Array{String,1},Base.#utf8}, ::Base.EltypeUnknown, ::Base.HasShape) at ./array.jl:250
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[3], in expression starting on line 5
# WARNING: utf8(s::AbstractString) is deprecated, use String(s) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in utf8(::String) at ./deprecated.jl:50
#  in collect_to!(::Array{String,1}, ::Base.Generator{Array{String,1},Base.#utf8}, ::Int64, ::Int64) at ./array.jl:269
#  in _collect(::Array{String,1}, ::Base.Generator{Array{String,1},Base.#utf8}, ::Base.EltypeUnknown, ::Base.HasShape) at ./array.jl:251
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[3], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[3], in expression starting on line 5
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-24

# %%
predictcount=252
rangelength=42
ta=ohlcv["Close"]
floattype=eltype(ta.values)
# Out:
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# in getindex at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# in getindex at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[4]:3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[4], in expression starting on line 3
# Float64

# %%
ustreasuryarray=renameta(quandl("USTREASURY/REALLONGTERM", startdate), ["USTREASURY/REALLONGTERM"])
ustreasuryarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[5], in expression starting on line 1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[5]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[5]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[5]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[5]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[5]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[5]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[5]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[5]:1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[5], in expression starting on line 1
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-24

# %%
gold=quandl("WGC/GOLD_DAILY_USD", startdate)
goldarray=TimeArray(gold.timestamp,gold.values./gold.values[1],["WGC/GOLD_DAILY_USD"])
goldarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[6], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[6], in expression starting on line 2
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-24

# %%
oilarray=renameta(quandl("OPEC/ORB", startdate)["Value"], ["OPEC/ORB"])
oilarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[7], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[7], in expression starting on line 1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[7]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[7]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[7]:1
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[7]:1
# in Type at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[7], in expression starting on line 1
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-23

# %%
eurusdarray=renameta(quandl("ECB/EURUSD", startdate)["Value"], ["ECB/EURUSD"])
eurusdarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[8], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[8], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[8], in expression starting on line 1
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-24

# %%
# CBOE/GVZ since 2008-6-3
half=floor(Int, rangelength/2)
gvzarray=renameta(ema(quandl("CBOE/GVZ", startdate)["GVZ"], half), ["CBOE/GVZ.ema$half"])
gvzarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[9], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[9], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[9], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[9], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[9], in expression starting on line 3
# 2-element Array{Date,1}:
#  2008-07-01
#  2016-06-23

# %%
# CBOE/EVZ since 2007-11-01
evzarray=renameta(ema(quandl("CBOE/EVZ", startdate)["EVZ"], half), ["CBOE/EVZ.ema$half"])
evzarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[10], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[10], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[10], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[10], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[10], in expression starting on line 2
# 2-element Array{Date,1}:
#  2007-12-04
#  2016-06-23

# %%
# CBOE/OVX since 2007-05-10
ovxarray=renameta(ema(quandl("CBOE/OVX", startdate)["USO_VIX_OVX_"], half), ["CBOE/OVX.ema$half"])
ovxarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[11], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[11], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[11], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[11], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[11], in expression starting on line 2
# 2-element Array{Date,1}:
#  2007-10-29
#  2016-06-23

# %%
aaii_weekly=quandl("AAII/AAII_SENTIMENT", startdate)
aaii_weekly.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[12], in expression starting on line 1
# 2-element Array{Date,1}:
#  2007-10-04
#  2016-06-23

# %%
usleading_weekly=quandl("ECRI/USLEADING", startdate)
usleading_weekly.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[13], in expression starting on line 1
# 2-element Array{Date,1}:
#  2007-10-05
#  2016-06-17

# %%
function overlaps(t1::Vector, t2::Vector)
    i = j = 1
    idx1 = Int[]
    idx2 = Int[]
    while i <= length(t1) && j <= length(t2)
        if t1[i] > t2[j]
            j += 1
        elseif t1[i] < t2[j]
            i += 1
        else
            push!(idx1, i)
            push!(idx2, j)
            i += 1
            j += 1
        end
    end
    (idx1, idx2)        
end
function merge2(ta1, ta2, columns=Void)
    idx1, idx2 = overlaps(ta1.timestamp, ta2.timestamp)
    vals = [ta1[idx1].values ta2[idx2].values]
    TimeArray(ta1[idx1].timestamp, vals, Void==columns?[ta1.colnames; ta2.colnames]:columns)
end
function ema_all(ta, n=42, p="")
    half=floor(Int, n/2)
    t0=ema(ta, half)
    t1=ema(ta, n)
    t2=ema(ta, n*2)
    t3=ema(ta, n*4)
    r=merge2(t0, t1)
    r=merge2(r, t2)
    r=merge2(r, t3)
    r2=merge2(t1.-t0, t2.-t1)
    r2=merge2(r2, t3.-t2)
    merge2(r, r2, [p*"ema$half", p*"ema$n", p*"ema$(n*2)", p*"ema$(n*4)", p*"ema$n-ema$half", p*"ema$(n*2)-ema$n", p*"ema$(n*4)-ema$(n*2)"])
end
function weekly_to_daily(weekly, daily)
    width=length(weekly.colnames)
    merged=merge2(weekly,daily)
    series=daily[merged.timestamp[1]:merged.timestamp[end]]
    sentiment=zeros(length(series),length(merged.colnames))
    for i in merged.timestamp
        idx1=searchsortedfirst(series.timestamp,i)
        idx2=searchsortedfirst(merged.timestamp,i)
        sentiment[idx1,:]=merged.values[idx2,:]
    end
#     # linear interpolation of 2 adjacent values
#     for i=2:length(merged.timestamp)
#         i1=merged.timestamp[i-1]
#         i2=merged.timestamp[i]
#         idx1=searchsortedfirst(series.timestamp,i1)
#         idx2=searchsortedfirst(series.timestamp,i2)
#         span=idx2-idx1
#         d=1/span
#         ds=collect(linspace(d,1-d,span-1))
#         for i=1:length(ds)
#             alpha=ds[i]
#             sentiment[idx1+i,:]=(1-alpha).*sentiment[idx1,:].+alpha.*sentiment[idx2,:]
#         end
#     end
#     last=searchsortedfirst(series.timestamp,merged.timestamp[end])
    last=1
    for i=last+1:size(sentiment,1)
        if sentiment[i,1]==0
            sentiment[i,:]=sentiment[i-1,:]
        end
    end
    TimeArray(series.timestamp,sentiment[:,1:width],merged.colnames[1:width])
end
function pad_daily(merged, daily)
    idx=searchsortedfirst(daily.timestamp, merged.timestamp[end])
    times=daily.timestamp[idx+1:end]
    n=length(times)
    if n>0
        values=merged.values[end,:]
        for i=2:n
            values=[values merged.values[end,:]]
        end
        values=transpose(values)
        TimeArray([merged.timestamp;times], [merged.values;values], merged.colnames)
    else
        TimeArray(merged.timestamp, merged.values, merged.colnames)
    end
end
function to_daily_and_pad(weekly, daily)
    merged=weekly_to_daily(weekly, daily)
    pad_daily(merged, daily)
end
# Out:
# to_daily_and_pad (generic function with 1 method)

# %%
ushybond=renameta(quandl("ML/HYOAS", startdate), ["ML/HYOAS"])
usaabond=renameta(quandl("ML/AAOAS", startdate), ["ML/AAOAS"])
[ushybond.timestamp[[1,end]] usaabond.timestamp[[1,end]]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[15], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[15], in expression starting on line 1

# %%
ushybondarray=pad_daily(ushybond, ta)
usaabondarray=pad_daily(usaabond, ta)
usyieldspreadarray=renameta(ushybondarray.-usaabondarray, ["ML/HYOAS-ML/AAOAS"])
usyieldspreadarray.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in pad_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:80
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in pad_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:80
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 2
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Base.UTF8String is deprecated, use String instead.
#   likely near In[16]:3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in .-(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in .-(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in .-(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .-(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[16], in expression starting on line 3
# 2-element Array{Date,1}:
#  2007-10-01
#  2016-06-24

# %%
aaii=to_daily_and_pad(aaii_weekly, ta)
aaiiarray=TimeArray(aaii.timestamp, aaii.values[:,[1:3;5:6]], ["AAII/AAII_SENTIMENT.Bullish","AAII/AAII_SENTIMENT.Neutral","AAII/AAII_SENTIMENT.Bearish","AAII.Bullish_8_Week_Mov_Avg","AAII.Bull_Bear_Spread"])
usleadingarray=renameta(to_daily_and_pad(usleading_weekly, ta), ["ECRI/USLEADING.Level", "ECRI/USLEADING.Growth"])
vxtharray=renameta(quandl("CBOE/VXTH", startdate), ["CBOE/VXTH"])
tyvixarray=renameta(ema(quandl("CBOE/TYVIX", startdate, 1), half), ["CBOE/TYVIX.ema$half"])
vvix=quandl("CBOE/VVIX", startdate)
vvixarray2=merge(vvix["VVIX"], ema(vvix, half), col_names=["CBOE/VVIX", "CBOE/VVIX.ema$half"])
vix=quandl("CBOE/VIX", startdate)
vixarray2=merge(vix["VIX_Close"], ema(vix, half), col_names=["CBOE/VIX", "CBOE/VIX.ema$half"])
vxv=quandl("CBOE/VXV", startdate)
vxvarray2=merge(vxv["CLOSE"], ema(vxv, half), col_names=["CBOE/VXV", "CBOE/VXV.ema$half"])
vvixarray=vvixarray2["CBOE/VVIX.ema$half"]
vixarray=vixarray2["CBOE/VIX.ema$half"]
vxvarray=vxvarray2["CBOE/VXV.ema$half"]
tmp=merge2(ema_all(eurusdarray, rangelength, "ECB/EURUSD."), ema_all(goldarray, rangelength, "WGC."))
tmp=merge2(tmp, ema_all(oilarray, rangelength, "OPEC/ORB."))
tmp=merge2(tmp, ema_all(ustreasuryarray, rangelength, "USTREASURY."))
emaarray=merge2(tmp, ema_all(vxtharray, rangelength, "CBOE/VXTH."))
[emaarray.timestamp[[1,end]] [size(emaarray.values)[1]; size(emaarray.values)[2]]]
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[17]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[17]:1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Date,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:201
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::StepRange{Date,Base.Dates.Day}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:205
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:40
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:68
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in pad_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:80
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:87
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:39
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Date,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:201
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::StepRange{Date,Base.Dates.Day}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:205
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:40
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in weekly_to_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:68
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:86
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in pad_daily(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:80
#  in to_daily_and_pad(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:87
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Int64) at ./In[2]:7
#  in quandl(::String, ::Date, ::Int64) at ./In[2]:17
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in renameta(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{String,1}) at ./In[2]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:15
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:17
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:18
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:27
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 8
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in sma(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:8
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:21
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #ema#2(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:26
#  in ema(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/movingaverages.jl:13
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:15
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:17
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:18
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #merge#6(::Array{String,1}, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/combine.jl:27
#  in (::Base.#kw##merge)(::Array{Any,1}, ::Base.#merge, ::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./null:0
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in csvtotimearray(::String, ::Type{T}) at ./In[2]:7
#  in quandl(::String, ::Date) at ./In[2]:15
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 10
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 11
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
# ...
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:34
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[14]:21
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:35
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[14]:21
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:35
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[14]:22
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:35
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{String,1}) at ./In[14]:22
#  in ema_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String) at ./In[14]:35
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[17], in expression starting on line 18
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64

# %%
function aroon(ta, n=25)
    up=moving(ta,x->findlast(x,maximum(x))/length(x),n)
    down=moving(ta,x->findlast(x,minimum(x))/length(x),n)
    d=up.-down
    r=merge2(up,down)
    r=merge2(r,d)
    TimeArray(r.timestamp,r.values,["aroon$n.up","aroon$n.down","aroon$n.up-down"])
end
function volumeoscillator(ohlcv, n=28, c="Volume")
    volume=ohlcv[c]
    vshort=ema(volume, int(n/2))
    vlong=ema(volume, n)
    volumeoscillator=(vshort.-vlong)./vlong
    TimeArray(volumeoscillator.timestamp,volumeoscillator.values,["VolumeOscillator$n"])
end
function chaikinmoneyflow(ohlcv, n=21, h="High", l="Low", c="Close", v="Volume")
    high=ohlcv[h]
    low=ohlcv[l]
    clo=ohlcv[c]
    volume=ohlcv[v]
    moneyflowvolume = (2.*clo.-low.-high)./(high.-low).*volume
    moneyflowsum=moving(moneyflowvolume,sum,n)
    volumesum=moving(volume,sum,n)
    re=moneyflowsum./volumesum
    TimeArray(re.timestamp, re.values, ["cmf$n"], ohlcv.meta)
end
function bollingerbands2{T,N}(ta::TimeArray{T,N}, ma::Int, width::Real)
    tama   = sma(ta, ma)
    upband = tama .+ moving(ta, std, ma) .* width .* sqrt((ma-1)/ma) # take out Bessel correction, per algorithm
    dnband = tama .- moving(ta, std, ma) .* width .* sqrt((ma-1)/ma)
    bands  =  merge(upband, dnband) 
    merge(bands, tama, col_names = ["up", "down", "mean"])
end
function bollingerbands_deviation(ta, n=20, width=2)
    bbands=bollingerbands2(ta,n,width)
    bbprice=merge2(bbands,ta)
    bbstd=(bbands.values[:,1].-bbands.values[:,3])./2
    bbdev=(bbprice.values[:,4].-bbands.values[:,3])./(bbands.values[:,1].-bbands.values[:,3])
    TimeArray(bbands.timestamp, [bbdev bbstd], ["bbdev$n,$width", "bbstd$n,$width"])
end
function bollingerbands_all(ta, n=20, width=2)
    b1=bollingerbands_deviation(ta, n, width)
    b2=bollingerbands_deviation(ta, n*2, width)
    b3=bollingerbands_deviation(ta, n*4, width)
    r=merge2(b1, b2)
    merge2(r, b3)
end
function vwap_divergence(ohlcv, n=28)
    v1=vwap(ohlcv, int(n/2))
    v2=vwap(ohlcv, n)
    v3=vwap(ohlcv, n*2)
    v4=vwap(ohlcv, n*4)
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
    cname=["vwap$(int(n/2))","vwap$n","vwap$(n*2)","vwap$(n*4)","vwap$(int(n/2))-$n","vwap$n-$(n*2)","vwap$(n*2)-$(n*4)"]#,"vwap$(n*8)","vwap$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
function averagetruerange(ohlc, n=14, h="High", l="Low", c="Close", real=floattype)
    highs = merge(ohlc[h], lag(ohlc[c]))
    lows = merge(ohlc[l], lag(ohlc[c]))
    hi=convert(Array{real,1},[maximum(highs.values[i,:]) for i=1:size(highs.values)[1]])
    lo=convert(Array{real,1},[minimum(lows.values[i,:]) for i=1:size(lows.values)[1]])
    truehigh = TimeArray(highs.timestamp, hi, ["hi"], highs.meta)
    truelow  = TimeArray(lows.timestamp, lo, ["lo"], lows.meta)
    res = ema(truehigh .- truelow, n, wilder=true)
    TimeArray(res.timestamp, res.values, ["atr$n"], ohlc.meta)
end
function atr_divergence(ohlcv, n=28)
    v1=averagetruerange(ohlcv,int(n/2));
    v2=averagetruerange(ohlcv,n);
    v3=averagetruerange(ohlcv,n*2);
    v4=averagetruerange(ohlcv,n*4);
    d1=v1.-v2
    d2=v2.-v3
    d3=v3.-v4
    ta=merge2(v1,v2)
    ta=merge2(ta,v3)
    ta=merge2(ta,v4)
    ta=merge2(ta,d1)
    ta=merge2(ta,d2)
    ta=merge2(ta,d3)
    cname=["atr$(int(n/2))","atr$n","atr$(n*2)","atr$(n*4)","atr$(int(n/2))-$n","atr$n-$(n*2)","atr$(n*2)-$(n*4)"]#,"atr$(n*8)","atr$(n*4)-$(n*8)"]
    TimeArray(ta.timestamp,ta.values,cname)
end
function moneyflowindex(ohlcv, n=14, h="High", l="Low", c="Close", v="Volume", real=floattype)
    hi=ohlcv[h]
    lo=ohlcv[l]
    cl=ohlcv[c]
    volume=ohlcv[v]
    typical=(hi.+lo.+cl)./3
    diff=typical.-lag(typical)
    positive=convert(Array{real,1},[i[2][1]>0?i[2][1]:0 for i in diff])
    negative=convert(Array{real,1},[i[2][1]<0?abs(i[2][1]):0 for i in diff])
    pv=TimeArray(diff.timestamp,positive,["Positive"]).*volume
    nv=TimeArray(diff.timestamp,negative,["Negative"]).*volume
    psum=moving(pv,sum,n)
    nsum=moving(nv,sum,n)
    re=psum./(psum.+nsum)
    TimeArray(re.timestamp, re.values, ["mfi$n"], ohlcv.meta)
end
function rsi_mfi_all(ohlcv, n=28, c="Close")
    ta=ohlcv[c]
    r1=rsi(ta,n)./100
    m1=moneyflowindex(ohlcv,n)
    merge2(r1,m1)
end
function macd2(ta, fast=12, slow=26, signal=9)
    mcd = ema(ta, fast) .- ema(ta, slow)
    sig = ema(mcd, signal)
    r = merge(mcd, sig, col_names=["macd($fast,$slow,$signal)", "signal"])
#     merge(r, mcd .- sig, col_names=[r.colnames; ["histogram"]])
end
function priceindex(ta, n=28)
    high=moving(ta, maximum, n)
    low=moving(ta, minimum, n)
    lh=merge(low, high, col_names = ["min", "max"])
    lh2=lh
    for i=1:n-1
        lh2=lead(lh2)
    end
    ranges=merge2(ta,lh2)
    index=[Real((i[2][1]-i[2][2])/(i[2][3]-i[2][2])) for i in ranges]
    TimeArray(ranges.timestamp, [ranges.values index], [ranges.colnames;["priceindex$n"]])
end
# Out:
# priceindex (generic function with 2 methods)

# %%
rsimfiarray=rsi_mfi_all(ohlcv,rangelength);
macdarray=macd2(ta,int(rangelength/2),rangelength);
vwaparray=vwap_divergence(ohlcv,rangelength);
atrarray=atr_divergence(ohlcv,rangelength);
aroonarray=aroon(ta,rangelength);
volumeoscillatorarray=volumeoscillator(ohlcv,rangelength);
cmfarray=chaikinmoneyflow(ohlcv,rangelength);
bbarray=bollingerbands_all(ta,rangelength,2);
priceindexarray=priceindex(ta,rangelength);
# Out:
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[19]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[19]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[19]:1
# WARNING: Base.Nothing is deprecated, use Void instead.
#   likely near In[19]:1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in rsi_mfi_all at ./In[18]:109 [inlined] (repeats 2 times)
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in #rsi#4(::Bool, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/MarketTechnicals/src/momentum.jl:27
#  in rsi_mfi_all at ./In[18]:110 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in ./(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:63
#  in rsi_mfi_all at ./In[18]:110 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:93
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:94
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:95
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::String) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:171
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:96
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in ./(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:63
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:97
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lag#2(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:133
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:98
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:98
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:98
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:98
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .-(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:98
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:101
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:101
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:101
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:101
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:101
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:102
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:102
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:102
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:102
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in .*(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:24
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:102
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in moving(::TimeSeries.TimeArray{Float64,1,DataType}, ::Base.#sum, ::Int64) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:178
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:103
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in moving(::TimeSeries.TimeArray{Float64,1,DataType}, ::Base.#sum, ::Int64) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:178
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:104
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:16
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:105
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:18
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:105
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in .+(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:19
#  in moneyflowindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64, ::String, ::String, ::String, ::String, ::Type{T}) at ./In[18]:105
#  in rsi_mfi_all at ./In[18]:111 [inlined]
#  in rsi_mfi_all(::TimeSeries.TimeArray{Float64,2,DataType}, ::Int64) at ./In[18]:109
#  in include_string(::String, ::String) at ./loading.jl:380
# ...
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in #lead#3(::Int64, ::Function, ::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in lead(::TimeSeries.TimeArray{Float64,2,DataType}) at /home/juser/.julia/v0.5/TimeSeries/src/apply.jl:145
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:126
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:128
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:128
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:128
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,1,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:128
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in priceindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Int64) at ./In[18]:130
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[19], in expression starting on line 9

# %%
featurearray=merge2(bbarray,cmfarray);
featurearray=merge2(featurearray,macdarray);
featurearray=merge2(featurearray,volumeoscillatorarray);
featurearray=merge2(featurearray,rsimfiarray);
featurearray=merge2(featurearray,aroonarray);
featurearray=merge2(featurearray,atrarray);
featurearray=merge2(featurearray,vwaparray);
featurearray=merge2(featurearray,ustreasuryarray);
featurearray=merge2(featurearray,ushybondarray);
featurearray=merge2(featurearray,usaabondarray);
featurearray=merge2(featurearray,usyieldspreadarray);
featurearray=merge2(featurearray,tyvixarray);
featurearray=merge2(featurearray,vxtharray);
featurearray=merge2(featurearray,vvixarray);
featurearray=merge2(featurearray,vixarray);
featurearray=merge2(featurearray,vxvarray);
featurearray=merge2(featurearray,goldarray);
featurearray=merge2(featurearray,gvzarray);
featurearray=merge2(featurearray,oilarray);
featurearray=merge2(featurearray,ovxarray);
featurearray=merge2(featurearray,eurusdarray);
featurearray=merge2(featurearray,evzarray);
featurearray=merge2(featurearray,aaiiarray);
featurearray=merge2(featurearray,usleadingarray);
featurearray=merge2(featurearray,emaarray);
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 3
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 4
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 7
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 8
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 8
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 8
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 8
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 9
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 10
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 10
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 10
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
# ...
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 22
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 22
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 23
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 23
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 23
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 23
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 24
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 24
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 24
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 24
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 25
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 25
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 25
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[20], in expression starting on line 25

# %%
withlabel=merge2(featurearray,priceindexarray)
withoutlabel=merge2(featurearray,ta)
withoutlabel.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,2,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 1
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,1,DataType}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,1}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,1,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:165
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:21
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:29
#  in getindex(::TimeSeries.TimeArray{Float64,2,DataType}, ::Array{Int64,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:160
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 2
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}, ::Type{T}) at ./In[14]:22
#  in merge2(::TimeSeries.TimeArray{Float64,2,DataType}, ::TimeSeries.TimeArray{Float64,1,DataType}) at ./In[14]:20
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[21], in expression starting on line 2
# 2-element Array{Date,1}:
#  2008-07-01
#  2016-06-23

# %%
dataoffset=length(withoutlabel)-length(withlabel)
lastdate=withlabel.timestamp[end]
lastdateidx=searchsortedfirst(withoutlabel.timestamp, lastdate)
splitidx=lastdateidx-predictcount+dataoffset
newfeatures=TimeArray(withoutlabel.timestamp[splitidx+1:end],withoutlabel.values[splitidx+1:end,:],withoutlabel.colnames)
training=TimeArray(withlabel.timestamp[1:splitidx],withlabel.values[1:splitidx,:],withlabel.colnames)
test=TimeArray(withlabel.timestamp[splitidx+1:end],withlabel.values[splitidx+1:end,:],withlabel.colnames)
test.timestamp[[1,end]]
# Out:
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[22], in expression starting on line 5
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[22], in expression starting on line 6
# WARNING: Union(args...) is deprecated, use Union{args...} instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in Union(::Type{T}, ::Type{T}) at ./deprecated.jl:50
#  in TimeSeries.TimeArray{Float64,2,DataType}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}, ::Type{Void}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:19
#  in TimeSeries.TimeArray{T,N,M}(::Array{Date,1}, ::Array{Float64,2}, ::Array{String,1}) at /home/juser/.julia/v0.5/TimeSeries/src/timearray.jl:33
#  in include_string(::String, ::String) at ./loading.jl:380
#  in execute_request_0x535c5df2(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.5/IJulia/src/execute_request.jl:183
#  in eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.5/IJulia/src/IJulia.jl:143
#  in (::IJulia.##24#30)() at ./task.jl:310
# while loading In[22], in expression starting on line 7
# 2-element Array{Date,1}:
#  2015-06-22
#  2016-04-27

# %%
rsiidx=findfirst(withlabel.colnames, "rsi")
mfiidx=findfirst(withlabel.colnames, "mfi$rangelength")
atridx=findfirst(withlabel.colnames, "atr$rangelength")
vxvidx=findfirst(withlabel.colnames, "CBOE/VXV.ema$half")
bbsidx=findfirst(withlabel.colnames, "AAII.Bull_Bear_Spread")
priceidx=findfirst(withlabel.colnames, "priceindex$rangelength")
closeidx=findfirst(withlabel.colnames, "Close")
randomfeaturenum=ceil(Int, sqrt(closeidx))
# Out:
# 10

# %%
plot(withoutlabel.timestamp,withoutlabel.values)
legend(withoutlabel.colnames,bbox_to_anchor=(1.62, 1.02))
title("Train model with $closeidx features $(training.timestamp[[1,end]])")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd044854e10>)

# %%
ntrees=100
features=training.values[:,1:closeidx]
labels=convert(Array{Float64,1},training.values[:,priceidx])
# train regression forest, using 2 random features, 10 trees,
# averaging of 5 samples per leaf (optional), 0.7 of samples per tree (optional)
model = build_forest(labels, features, randomfeaturenum, ntrees, 5, 0.7)
# Out:
# Ensemble of Decision Trees
# Trees:      100
# Avg Leaves: 420.11
# Avg Depth:  29.0

# %%
newlabels=apply_forest(model, newfeatures.values);
initvalue=withlabel.values[1,closeidx];

# %%
plot(withoutlabel.timestamp,withoutlabel.values[:,closeidx]./initvalue)
plot(withlabel.timestamp,withlabel.values[:,closeidx+1:closeidx+2]./initvalue)
plot(withoutlabel.timestamp,withoutlabel.values[:,rsiidx])
plot(withoutlabel.timestamp,withoutlabel.values[:,mfiidx])
plot(withoutlabel.timestamp,withoutlabel.values[:,atridx]./withoutlabel.values[1,atridx])
plot(withoutlabel.timestamp,withoutlabel.values[:,vxvidx]./withoutlabel.values[1,vxvidx],c="Coral")
plot(withoutlabel.timestamp,withoutlabel.values[:,bbsidx])
plot(training.timestamp,training.values[:,priceidx],c="Grey")
plot(newfeatures.timestamp,newlabels,c="k")
title("$symbol history & forecast $(withoutlabel.timestamp[[1,end]])")
grid("on")
axhline(y=-0.25,ls="-.",c="Grey")
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
legend([withlabel.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx,mfiidx,atridx,vxvidx,bbsidx,priceidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd03d7619d0>)
# PyObject <matplotlib.legend.Legend object at 0x7fd03c4d8c10>

# %%
plot(newfeatures.timestamp,newfeatures.values[:,closeidx]./initvalue)
plot(test.timestamp,test.values[:,closeidx+1:closeidx+2]./initvalue)
plot(newfeatures.timestamp,newfeatures.values[:,rsiidx])
plot(newfeatures.timestamp,newfeatures.values[:,mfiidx])
plot(newfeatures.timestamp,newfeatures.values[:,atridx]./withoutlabel.values[1,atridx])
plot(newfeatures.timestamp,newfeatures.values[:,vxvidx]./withoutlabel.values[1,vxvidx],c="Coral")
plot(newfeatures.timestamp,newfeatures.values[:,bbsidx])
plot(test.timestamp,test.values[:,priceidx],c="Grey")
plot(newfeatures.timestamp,newlabels,c="k")
legend([test.colnames[[closeidx,closeidx+1,closeidx+2,rsiidx,mfiidx,atridx,vxvidx,bbsidx,priceidx]];"priceindex$rangelength forecast"],bbox_to_anchor=(1.5, 1.02))
title("$symbol forecast: $ntrees trees, $randomfeaturenum features/node, $rangelength days $(newfeatures.timestamp[[1,end]])", loc="left")
grid("on")
# color names http://astropython.blogspot.ie/2012/02/additional-color-names-for-matplotlib.html
# http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.axhline
axhline(y=-0.25,ls="-.",c="Grey")
axhline(y=0.25,ls="-.",c="Grey")
axhline(y=0.75,ls="-.",c="Grey")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd03d06fb90>)
# PyObject <matplotlib.lines.Line2D object at 0x7fd03c2e9710>

# %%
features=withlabel.values[:,1:closeidx]
labels=convert(Array{Float64,1},withlabel.values[:,priceidx])
# run n-fold cross validation on regression forest
# using 2 random features, 10 trees, 3 folds, averaging of 5 samples/leaf (optional),
# and 0.7 porition of samples per tree (optional)
# returns array of coefficients of determination (R^2)
r2 = nfoldCV_forest(labels, features, 2, ntrees, 3, 5, 0.7)
# Out:
# Fold 1
# Mean Squared Error:     0.013124759952730639
# Correlation Coeff:      0.9504340785197969
# Coeff of Determination: 0.8809515856436015
#
# Fold 2
# Mean Squared Error:     0.012532163957448474
# Correlation Coeff:      0.9566416745919043
# Coeff of Determination: 0.8890844022633395
#
# Fold 3
# Mean Squared Error:     0.012582613773020633
# Correlation Coeff:      0.9468737348224784
# Coeff of Determination: 0.8818078055142929
#
# Mean Coeff of Determination: 0.8839479311404114
# 3-element Array{Float64,1}:
#  0.880952
#  0.889084
#  0.881808

# %%
plot(vxtharray.timestamp, vxtharray.values)
plot(vvixarray2.timestamp, vvixarray2.values)
plot(vixarray2.timestamp, vixarray2.values)
plot(vxvarray2.timestamp, vxvarray2.values)
plot(aaiiarray.timestamp, aaiiarray["AAII.Bull_Bear_Spread"].values.*40)
legend(["CBOE/VXTH","CBOE/VVIX","CBOE/VVIX.ema$half","CBOE/VIX","CBOE/VIX.ema$half","CBOE/VXV","CBOE/VXV.ema$half","AAII.Bull_Bear_Spread"],bbox_to_anchor=(1.54, 1.02))
grid("on")
axhline(y=10,ls="-.",c="Grey")
axhline(y=-10,ls="-.",c="Grey")
title("$symbol volatility $(vxtharray.timestamp[[1,end]])")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd03d208bd0>)
